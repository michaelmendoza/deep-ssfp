# %%
import os
import sys
sys.path.insert(0, '../..')
import numpy as np
import matplotlib.pyplot as plt
import mssfp
import deepssfp
import deepssfp.analysis

# %%
modes=['BandRemoval:4', 'BandRemoval:2', 'SuperFOV', 'SuperFOVi', 'SyntheticBanding']
model_dir = "D:/DeepSSFP/brain_phantom/"
model_name="brain_phantom"

# %%
rawdata = deepssfp.analysis.create_brain_rawdata()

mode = modes[1]
ds = deepssfp.dataset.Dataset(mode, input_data=rawdata['M'])
model_dict = deepssfp.analysis.run_training(ds, mode, model_name, model_dir, train_model=True, verbose=False)
pred, target = deepssfp.analysis.run_inference_on_test_dataset(ds, model_dict['model'], verbose=False)
metrics = deepssfp.analysis.compute_image_metrics(pred, target, verbose=True)
# Out:
# Generating phantom...
# Generating 3D phantom: (120, 434, 362)
# Generating SSFP dataset...
# c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\simulations\ssfp.py:65: RuntimeWarning: divide by zero encountered in divide
#   E1 = np.where(T1 > 0, np.exp(-TR / T1), 0)
# c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\simulations\ssfp.py:66: RuntimeWarning: divide by zero encountered in divide
#   E2 = np.where(T2 > 0, np.exp(-TR / T2), 0)
# c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\simulations\ssfp.py:92: RuntimeWarning: divide by zero encountered in divide
#   T2_decay = np.where(T2 > 0, np.exp(-TE / T2), 0)
# Dataset complete.
# Dataset shape: (120, 256, 256, 4)
# Dataset: mode:BandRemoval:2, size:120 height:256 width:256 cin:4 cout:2 ratio:0.8 dtype: float64, float64
# 2025-05-29 22:08:04,412 - DeepSSFP - INFO - Loading model from path: D:/DeepSSFP/brain_phantom/brain_phantom_dataaug_bandremoval_2
# 2025-05-29 22:08:06,200 - DeepSSFP - INFO - Model loaded successfully from D:/DeepSSFP/brain_phantom/brain_phantom_dataaug_bandremoval_2.keras
# 2025-05-29 22:08:06,201 - DeepSSFP - INFO - Loading training history from D:/DeepSSFP/brain_phantom/brain_phantom_dataaug_bandremoval_2_history.npz
# 2025-05-29 22:08:06,254 - DeepSSFP - INFO - Making predictions on data with shape (24, 256, 256, 4)
# 2025-05-29 22:08:10,781 - DeepSSFP - INFO - Predictions complete. Output shape: (24, 256, 256, 2)
# mse: 2.92e-06 +/- 5.65e-07 mae: 9.93e-04 +/- 5.64e-05 psnr: 43.0640 +/- 6.62e-01 ssim: 9.94e-01 +/- 3.73e-04 nrmse: 2.10e-02 +/- 1.78e-03
