# %%
import os
import sys
sys.path.insert(0, '../..')
import numpy as np
import matplotlib.pyplot as plt
import mssfp
import deepssfp

print(mssfp.__version__)
# Out:
# 0.0.6

# %%
import deepssfp.dataloader
filedir = 'C:/Users/mmend/projects/mri/data/2022_06_28_Imperial-DeepSSFP'
filename = 'meas_MID110_bSSFP_brain_fa70_1x1x2_forMichael_FID24972.dat'
file = os.path.join(filedir, filename)
data = deepssfp.dataloader.read_rawdata(file, doChaAverage = True, doAveAverage = True)
# Out:
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/13.6G [00:00<?, ?B/s]
# read data:   0%|          | 0/115200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 5
#       3 filename = 'meas_MID110_bSSFP_brain_fa70_1x1x2_forMichael_FID24972.dat'
#       4 file = os.path.join(filedir, filename)
# ----> 5 data = deepssfp.dataloader.read_rawdata(file, doChaAverage = True, doAveAverage = True)
#
# File c:\Users\mmend\projects\mri\deep-ssfp-mri\deepssfp\dataloader.py:84, in read_rawdata(filepath, datatype, doChaAverage, doChaSOSAverage, doAveAverage)
#      82 twixObj = mapvbvd.mapVBVD(filepath)
#      83 twixObj.image.squeeze = True
# ---> 84 data = twixObj.image['']
#      85 sqzDims = twixObj.image.sqzDims.copy()  # Create a copy to modify
#      87 # Move Lin to be first index
#
# ...
