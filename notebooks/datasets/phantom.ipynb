# %%
import os
import sys
sys.path.insert(0, '../..')
import numpy as np
import matplotlib.pyplot as plt
import mssfp
import deepssfp

print(mssfp.__version__)
# Out:
# 0.0.6

# %%
import deepssfp.dataloader
filepath = 'C:/Users/mmend/projects/mri/data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom'

filesets = deepssfp.dataloader.load_filepaths()
print(filesets)

M = []
for file in filesets[4:8]:
    data = deepssfp.dataloader.read_rawdata(file, doChaAverage = True, doAveAverage = True)
    M.append(data['data'])

# Prepare data 
m = np.stack(M[0:4], axis=-1)
# Out:
# [[WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID158_trufi_phi0_FID6703.dat'), WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID159_trufi_phi90_FID6704.dat'), WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID160_trufi_phi180_FID6705.dat'), WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID162_trufi_phi270_FID6707.dat')], [WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID164_trufi_phi0_FID6709.dat'), WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID165_trufi_phi90_FID6710.dat'), WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID166_trufi_phi180_FID6711.dat'), WindowsPath('../../../data/2017_DeepSSFP/11062017_SSFP_Smoothing_DL_Phantom/meas_MID167_trufi_phi270_FID6712.dat')]]
# pymapVBVD version 0.4.8
# Software version: VB
# ...

# %%
print(m.shape)
plt.imshow(np.abs(m[64, :, :, 0]), cmap='gray')
plt.show()
# Out:
# (128, 152, 256, 4)

# %%
filepath = 'C:/Users/mmend/projects/mri/data/2017_DeepSSFP/10282017_SSPF Smoothing DL'

filesets = deepssfp.dataloader.load_filepaths(filepath)
filesets = [file for file in filesets if 'trufi' in str(file)]
print(filesets)

M = []
for file in filesets:
    data = deepssfp.dataloader.read_rawdata(file, doChaAverage = True, doAveAverage = True)
    print(data['data'].shape)
    M.append(data['data'])

# Prepare data 
m = np.stack(M[0:4], axis=-1)
# Out:
# [WindowsPath('C:/Users/mmend/projects/mri/data/2017_DeepSSFP/10282017_SSPF Smoothing DL/meas_MID885_trufi_phi0_FID4833.dat'), WindowsPath('C:/Users/mmend/projects/mri/data/2017_DeepSSFP/10282017_SSPF Smoothing DL/meas_MID894_trufi_phi90_FID4842.dat'), WindowsPath('C:/Users/mmend/projects/mri/data/2017_DeepSSFP/10282017_SSPF Smoothing DL/meas_MID903_trufi_phi180_FID4851.dat'), WindowsPath('C:/Users/mmend/projects/mri/data/2017_DeepSSFP/10282017_SSPF Smoothing DL/meas_MID912_trufi_phi270_FID4860.dat')]
# pymapVBVD version 0.4.8
# Software version: VB
# Scan 1/1, read all mdhs:   0%|          | 0.00/2.06G [00:00<?, ?B/s]
# read data:   0%|          | 0/65535 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 9
#       7 M = []
#       8 for file in filesets:
# ...

# %%
print(m.shape)
plt.imshow(np.abs(m[64, :, :, 0]), cmap='gray')
plt.show()
# Out:
# (128, 152, 256, 4)
