# %%
import sys
sys.path.insert(0, '../..')
import numpy as np
import matplotlib.pyplot as plt 
import mssfp
from deepssfp import dataloader, view, recon, dataset, dataformatter, deepssfp, models, plotlib

# %%
data = mssfp.generate_ssfp_dataset(N=128, npcs=4, f=500, alpha=np.deg2rad(60), sigma=0.005, rotate=True, deform=True)['M']
data.shape
# Out:
# Generating 3d phantom:(5240, 434, 362)
# 100%|██████████| 5240/5240 [00:49<00:00, 105.03it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = mssfp.generate_ssfp_dataset(N=128, npcs=4, f=500, alpha=np.deg2rad(60), sigma=0.005, rotate=True, deform=True)['M']
#       2 data.shape
#
# File c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\phantoms\phantom.py:78, in generate_ssfp_dataset(N, npcs, f, TR, TE, alpha, sigma, path, data_indices, rotate, deform)
#      75     M = add_noise_gaussian(M, sigma=sigma)
#      76     dataset.append(M[None, ...])
# ---> 78 dataset = np.concatenate(dataset, axis=0)
#      79 return { 'M': dataset, 'phantom': phantom }
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 5.12 GiB for an array with shape (5240, 128, 128, 4) and data type complex128

# %%
mode = 'SyntheticBanding'
model, history, ds, predictions = deepssfp.train(mode, epochs=400)
