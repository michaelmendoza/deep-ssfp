# %%
import os
import sys
sys.path.insert(0, '../..')
import numpy as np
import matplotlib.pyplot as plt
import mssfp
import deepssfp

print(mssfp.__version__)
# Out:
# 0.0.6

# %%
mode = deepssfp.DataMode.SyntheticBanding2.value
model_name = "block_phantom_T2maps"
model_dir = "D:/DeepSSFP/"

# %%
slices = 200
tissue_parameters = {
    0: ('none', 0, 0, 0),
    1: ('fat', 0.350, 0.130, 0),
    2: ('bone marrow', 0.370, 0.05, 0),
    3: ('liver', 0.8, 0.04, 0),
    4: ('white matter', 1.0, 0.08, 0),
    5: ('myocardium', 1.150, 0.045, 0),
    6: ('vessels', 1.2, 0.05, 0),   
    7: ('gray matter', 1.3, 0.110, 0),
    8: ('muscle', 1.4, 0.030, 0),
    9: ('CSF', 4.0, 1.0, 0)
}

dataset = mssfp.generate_ssfp_dataset(
    phantom_type='block', 
    slices=slices, 
    shape=128, 
    ids=[1, 2, 3, 4, 5, 6, 7, 8, 9],
    tissues = tissue_parameters,
    npcs=8, 
    f=500, 
    alpha=np.deg2rad(60), 
    sigma=0.001, 
    data_indices=[(0, 2), (120,180)], 
    useRotate=True, 
    useDeform=True
)
mssfp.plot_dataset(dataset['M'], slice=0)
# Out:
# Generating phantom...
# Generating SSFP dataset...
# c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\simulations\ssfp.py:65: RuntimeWarning: divide by zero encountered in divide
#   E1 = np.where(T1 > 0, np.exp(-TR / T1), 0)
# c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\simulations\ssfp.py:66: RuntimeWarning: divide by zero encountered in divide
#   E2 = np.where(T2 > 0, np.exp(-TR / T2), 0)
# c:\Users\mmend\.conda\envs\mri\lib\site-packages\mssfp\simulations\ssfp.py:92: RuntimeWarning: divide by zero encountered in divide
#   T2_decay = np.where(T2 > 0, np.exp(-TE / T2), 0)
# Dataset complete.
# Dataset shape: (200, 128, 128, 8)

# %%
import deepssfp.analysis
results = deepssfp.analysis.run_experiment(
    mode=mode, 
    model_name=model_name,
    model_dir=model_dir,
    train_model=True,
    custom_dataset=dataset
)
# Out:
# ===== Running experiment: SyntheticBanding:2 =====
# Model path: D:/DeepSSFP/block_phantom_T2maps_syntheticbanding_2
# Dataset path: D:/DeepSSFP/block_phantom_T2maps_dataset.npy
# Creating ds ...
# Data shape: (200, 128, 128, 8)
# Formatting data...
# Dataset: mode:SyntheticBanding:2, size:200 height:128 width:128 cin:4 cout:12 ratio:0.8
# dtype: float64, float64
# Generating scaler... for mode: SyntheticBanding:2
# Training data shape: (160, 128, 128, 4), (160, 128, 128, 12)
# Input scaler stats: mean=-0.0041, std=0.0674
# Output scaler stats: mean=-0.0038, std=0.0677
# Selected indices: [19 18 10]
# Figure size: (16, 6)
# 2025-04-22 23:20:11,595 - DeepSSFP - INFO - Model will be saved to: D:/DeepSSFP/block_phantom_T2maps_syntheticbanding_2
# 2025-04-22 23:20:11,596 - DeepSSFP - INFO - Training DataSet: (160, 128, 128, 4) | (160, 128, 128, 12)
# 2025-04-22 23:20:11,597 - DeepSSFP - INFO - Test DataSet: (40, 128, 128, 4) | (40, 128, 128, 12)
# Training model...
# 2025-04-22 23:20:12,666 - DeepSSFP - INFO - Creating new model with dimensions: 128x128x4→12
# 2025-04-22 23:20:13,497 - DeepSSFP - INFO - Model created: unet
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 1184        img[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  1179904     dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  295040      dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   73792       dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 18464       dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 12) 396         dropout_8[0][0]
# ==================================================================================================
# Total params: 8,637,036
# Trainable params: 8,634,092
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Epoch 1/800
# 20/20 - 13s - loss: 0.9772 - mean_absolute_error: 0.6450 - val_loss: 1.2962 - val_mean_absolute_error: 0.6885
#
# Epoch 00001: val_loss improved from inf to 1.29623, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 2/800
# 20/20 - 1s - loss: 0.3113 - mean_absolute_error: 0.3690 - val_loss: 0.3731 - val_mean_absolute_error: 0.4422
#
# Epoch 00002: val_loss improved from 1.29623 to 0.37306, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 3/800
# 20/20 - 1s - loss: 0.2152 - mean_absolute_error: 0.3008 - val_loss: 0.1101 - val_mean_absolute_error: 0.2404
#
# Epoch 00003: val_loss improved from 0.37306 to 0.11014, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 4/800
# 20/20 - 1s - loss: 0.1835 - mean_absolute_error: 0.2740 - val_loss: 0.0508 - val_mean_absolute_error: 0.1553
#
# Epoch 00004: val_loss improved from 0.11014 to 0.05076, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 5/800
# 20/20 - 1s - loss: 0.1650 - mean_absolute_error: 0.2582 - val_loss: 0.0364 - val_mean_absolute_error: 0.1262
#
# Epoch 00005: val_loss improved from 0.05076 to 0.03638, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 6/800
# 20/20 - 1s - loss: 0.1514 - mean_absolute_error: 0.2460 - val_loss: 0.0294 - val_mean_absolute_error: 0.1095
#
# Epoch 00006: val_loss improved from 0.03638 to 0.02936, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 7/800
# 20/20 - 1s - loss: 0.1402 - mean_absolute_error: 0.2359 - val_loss: 0.0228 - val_mean_absolute_error: 0.0960
#
# Epoch 00007: val_loss improved from 0.02936 to 0.02281, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 8/800
# 20/20 - 1s - loss: 0.1292 - mean_absolute_error: 0.2257 - val_loss: 0.0200 - val_mean_absolute_error: 0.0893
#
# Epoch 00008: val_loss improved from 0.02281 to 0.02004, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 9/800
# 20/20 - 1s - loss: 0.1206 - mean_absolute_error: 0.2171 - val_loss: 0.0174 - val_mean_absolute_error: 0.0832
#
# Epoch 00009: val_loss improved from 0.02004 to 0.01743, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 10/800
# 20/20 - 1s - loss: 0.1121 - mean_absolute_error: 0.2088 - val_loss: 0.0171 - val_mean_absolute_error: 0.0821
#
# Epoch 00010: val_loss improved from 0.01743 to 0.01710, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 11/800
# 20/20 - 1s - loss: 0.1049 - mean_absolute_error: 0.2012 - val_loss: 0.0141 - val_mean_absolute_error: 0.0749
#
# Epoch 00011: val_loss improved from 0.01710 to 0.01413, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 12/800
# 20/20 - 1s - loss: 0.0979 - mean_absolute_error: 0.1938 - val_loss: 0.0118 - val_mean_absolute_error: 0.0681
#
# Epoch 00012: val_loss improved from 0.01413 to 0.01176, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 13/800
# 20/20 - 1s - loss: 0.0917 - mean_absolute_error: 0.1871 - val_loss: 0.0101 - val_mean_absolute_error: 0.0634
#
# Epoch 00013: val_loss improved from 0.01176 to 0.01011, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 14/800
# 20/20 - 1s - loss: 0.0858 - mean_absolute_error: 0.1806 - val_loss: 0.0099 - val_mean_absolute_error: 0.0632
#
# Epoch 00014: val_loss improved from 0.01011 to 0.00994, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 15/800
# 20/20 - 1s - loss: 0.0811 - mean_absolute_error: 0.1749 - val_loss: 0.0104 - val_mean_absolute_error: 0.0648
#
# Epoch 00015: val_loss did not improve from 0.00994
# Learning rate: 0.0010
# Epoch 16/800
# 20/20 - 1s - loss: 0.0760 - mean_absolute_error: 0.1691 - val_loss: 0.0092 - val_mean_absolute_error: 0.0607
#
# Epoch 00016: val_loss improved from 0.00994 to 0.00918, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 17/800
# 20/20 - 1s - loss: 0.0719 - mean_absolute_error: 0.1640 - val_loss: 0.0078 - val_mean_absolute_error: 0.0563
#
# Epoch 00017: val_loss improved from 0.00918 to 0.00780, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 18/800
# 20/20 - 1s - loss: 0.0677 - mean_absolute_error: 0.1591 - val_loss: 0.0086 - val_mean_absolute_error: 0.0586
#
# Epoch 00018: val_loss did not improve from 0.00780
# Learning rate: 0.0010
# Epoch 19/800
# 20/20 - 1s - loss: 0.0639 - mean_absolute_error: 0.1543 - val_loss: 0.0090 - val_mean_absolute_error: 0.0581
#
# Epoch 00019: val_loss did not improve from 0.00780
# Learning rate: 0.0010
# Epoch 20/800
# 20/20 - 1s - loss: 0.0608 - mean_absolute_error: 0.1500 - val_loss: 0.0071 - val_mean_absolute_error: 0.0534
#
# Epoch 00020: val_loss improved from 0.00780 to 0.00706, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 21/800
# 20/20 - 1s - loss: 0.0576 - mean_absolute_error: 0.1457 - val_loss: 0.0058 - val_mean_absolute_error: 0.0481
#
# Epoch 00021: val_loss improved from 0.00706 to 0.00579, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 22/800
# 20/20 - 1s - loss: 0.0547 - mean_absolute_error: 0.1418 - val_loss: 0.0067 - val_mean_absolute_error: 0.0501
#
# Epoch 00022: val_loss did not improve from 0.00579
# Learning rate: 0.0010
# Epoch 23/800
# 20/20 - 1s - loss: 0.0522 - mean_absolute_error: 0.1382 - val_loss: 0.0074 - val_mean_absolute_error: 0.0538
#
# Epoch 00023: val_loss did not improve from 0.00579
# Learning rate: 0.0010
# Epoch 24/800
# 20/20 - 1s - loss: 0.0498 - mean_absolute_error: 0.1347 - val_loss: 0.0059 - val_mean_absolute_error: 0.0488
#
# Epoch 00024: val_loss did not improve from 0.00579
# Learning rate: 0.0010
# Epoch 25/800
# 20/20 - 1s - loss: 0.0471 - mean_absolute_error: 0.1308 - val_loss: 0.0062 - val_mean_absolute_error: 0.0472
#
# Epoch 00025: val_loss did not improve from 0.00579
# Learning rate: 0.0010
# Epoch 26/800
# 20/20 - 1s - loss: 0.0450 - mean_absolute_error: 0.1276 - val_loss: 0.0056 - val_mean_absolute_error: 0.0457
#
# Epoch 00026: val_loss improved from 0.00579 to 0.00558, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 27/800
# 20/20 - 1s - loss: 0.0430 - mean_absolute_error: 0.1245 - val_loss: 0.0058 - val_mean_absolute_error: 0.0460
#
# Epoch 00027: val_loss did not improve from 0.00558
# Learning rate: 0.0010
# Epoch 28/800
# 20/20 - 1s - loss: 0.0411 - mean_absolute_error: 0.1215 - val_loss: 0.0046 - val_mean_absolute_error: 0.0431
#
# Epoch 00028: val_loss improved from 0.00558 to 0.00464, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 29/800
# 20/20 - 1s - loss: 0.0399 - mean_absolute_error: 0.1196 - val_loss: 0.0042 - val_mean_absolute_error: 0.0403
#
# Epoch 00029: val_loss improved from 0.00464 to 0.00422, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 30/800
# 20/20 - 1s - loss: 0.0378 - mean_absolute_error: 0.1161 - val_loss: 0.0042 - val_mean_absolute_error: 0.0403
#
# Epoch 00030: val_loss did not improve from 0.00422
# Learning rate: 0.0010
# Epoch 31/800
# 20/20 - 1s - loss: 0.0370 - mean_absolute_error: 0.1147 - val_loss: 0.0047 - val_mean_absolute_error: 0.0440
#
# Epoch 00031: val_loss did not improve from 0.00422
# Learning rate: 0.0010
# Epoch 32/800
# 20/20 - 1s - loss: 0.0352 - mean_absolute_error: 0.1115 - val_loss: 0.0051 - val_mean_absolute_error: 0.0430
#
# Epoch 00032: val_loss did not improve from 0.00422
# Learning rate: 0.0010
# Epoch 33/800
# 20/20 - 1s - loss: 0.0338 - mean_absolute_error: 0.1093 - val_loss: 0.0059 - val_mean_absolute_error: 0.0452
#
# Epoch 00033: val_loss did not improve from 0.00422
# Learning rate: 0.0010
# Epoch 34/800
# 20/20 - 1s - loss: 0.0326 - mean_absolute_error: 0.1075 - val_loss: 0.0049 - val_mean_absolute_error: 0.0450
#
# Epoch 00034: val_loss did not improve from 0.00422
# Learning rate: 0.0010
# Epoch 35/800
# 20/20 - 1s - loss: 0.0316 - mean_absolute_error: 0.1057 - val_loss: 0.0038 - val_mean_absolute_error: 0.0384
#
# Epoch 00035: val_loss improved from 0.00422 to 0.00380, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 36/800
# 20/20 - 1s - loss: 0.0308 - mean_absolute_error: 0.1040 - val_loss: 0.0038 - val_mean_absolute_error: 0.0372
#
# Epoch 00036: val_loss improved from 0.00380 to 0.00377, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 37/800
# 20/20 - 1s - loss: 0.0296 - mean_absolute_error: 0.1017 - val_loss: 0.0034 - val_mean_absolute_error: 0.0361
#
# Epoch 00037: val_loss improved from 0.00377 to 0.00342, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 38/800
# 20/20 - 1s - loss: 0.0282 - mean_absolute_error: 0.0992 - val_loss: 0.0036 - val_mean_absolute_error: 0.0365
#
# Epoch 00038: val_loss did not improve from 0.00342
# Learning rate: 0.0010
# Epoch 39/800
# 20/20 - 1s - loss: 0.0273 - mean_absolute_error: 0.0975 - val_loss: 0.0038 - val_mean_absolute_error: 0.0391
#
# Epoch 00039: val_loss did not improve from 0.00342
# Learning rate: 0.0010
# Epoch 40/800
# 20/20 - 1s - loss: 0.0267 - mean_absolute_error: 0.0963 - val_loss: 0.0036 - val_mean_absolute_error: 0.0359
#
# Epoch 00040: val_loss did not improve from 0.00342
# Learning rate: 0.0010
# Epoch 41/800
# 20/20 - 1s - loss: 0.0257 - mean_absolute_error: 0.0943 - val_loss: 0.0031 - val_mean_absolute_error: 0.0337
#
# Epoch 00041: val_loss improved from 0.00342 to 0.00314, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 42/800
# 20/20 - 1s - loss: 0.0249 - mean_absolute_error: 0.0928 - val_loss: 0.0034 - val_mean_absolute_error: 0.0356
#
# Epoch 00042: val_loss did not improve from 0.00314
# Learning rate: 0.0010
# Epoch 43/800
# 20/20 - 1s - loss: 0.0243 - mean_absolute_error: 0.0918 - val_loss: 0.0045 - val_mean_absolute_error: 0.0379
#
# Epoch 00043: val_loss did not improve from 0.00314
# Learning rate: 0.0010
# Epoch 44/800
# 20/20 - 1s - loss: 0.0242 - mean_absolute_error: 0.0912 - val_loss: 0.0037 - val_mean_absolute_error: 0.0366
#
# Epoch 00044: val_loss did not improve from 0.00314
# Learning rate: 0.0010
# Epoch 45/800
# 20/20 - 1s - loss: 0.0232 - mean_absolute_error: 0.0896 - val_loss: 0.0033 - val_mean_absolute_error: 0.0371
#
# Epoch 00045: val_loss did not improve from 0.00314
# Learning rate: 0.0010
# Epoch 46/800
# 20/20 - 2s - loss: 0.0229 - mean_absolute_error: 0.0887 - val_loss: 0.0038 - val_mean_absolute_error: 0.0363
#
# Epoch 00046: val_loss did not improve from 0.00314
# Learning rate: 0.0010
# Epoch 47/800
# 20/20 - 1s - loss: 0.0224 - mean_absolute_error: 0.0876 - val_loss: 0.0036 - val_mean_absolute_error: 0.0373
#
# Epoch 00047: val_loss did not improve from 0.00314
# Learning rate: 0.0010
# Epoch 48/800
# 20/20 - 1s - loss: 0.0218 - mean_absolute_error: 0.0865 - val_loss: 0.0029 - val_mean_absolute_error: 0.0325
#
# Epoch 00048: val_loss improved from 0.00314 to 0.00290, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 49/800
# 20/20 - 1s - loss: 0.0216 - mean_absolute_error: 0.0858 - val_loss: 0.0027 - val_mean_absolute_error: 0.0316
#
# Epoch 00049: val_loss improved from 0.00290 to 0.00272, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 50/800
# 20/20 - 1s - loss: 0.0210 - mean_absolute_error: 0.0845 - val_loss: 0.0032 - val_mean_absolute_error: 0.0330
#
# Epoch 00050: val_loss did not improve from 0.00272
# Learning rate: 0.0010
# Epoch 51/800
# 20/20 - 1s - loss: 0.0207 - mean_absolute_error: 0.0838 - val_loss: 0.0029 - val_mean_absolute_error: 0.0339
#
# Epoch 00051: val_loss did not improve from 0.00272
# Learning rate: 0.0010
# Epoch 52/800
# 20/20 - 1s - loss: 0.0203 - mean_absolute_error: 0.0830 - val_loss: 0.0027 - val_mean_absolute_error: 0.0324
#
# Epoch 00052: val_loss did not improve from 0.00272
# Learning rate: 0.0010
# Epoch 53/800
# 20/20 - 1s - loss: 0.0199 - mean_absolute_error: 0.0822 - val_loss: 0.0026 - val_mean_absolute_error: 0.0314
#
# Epoch 00053: val_loss improved from 0.00272 to 0.00258, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 54/800
# 20/20 - 1s - loss: 0.0193 - mean_absolute_error: 0.0811 - val_loss: 0.0032 - val_mean_absolute_error: 0.0345
#
# Epoch 00054: val_loss did not improve from 0.00258
# Learning rate: 0.0010
# Epoch 55/800
# 20/20 - 1s - loss: 0.0191 - mean_absolute_error: 0.0802 - val_loss: 0.0026 - val_mean_absolute_error: 0.0319
#
# Epoch 00055: val_loss improved from 0.00258 to 0.00258, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 56/800
# 20/20 - 1s - loss: 0.0186 - mean_absolute_error: 0.0793 - val_loss: 0.0027 - val_mean_absolute_error: 0.0318
#
# Epoch 00056: val_loss did not improve from 0.00258
# Learning rate: 0.0010
# Epoch 57/800
# 20/20 - 1s - loss: 0.0182 - mean_absolute_error: 0.0782 - val_loss: 0.0026 - val_mean_absolute_error: 0.0319
#
# Epoch 00057: val_loss did not improve from 0.00258
# Learning rate: 0.0010
# Epoch 58/800
# 20/20 - 1s - loss: 0.0181 - mean_absolute_error: 0.0777 - val_loss: 0.0026 - val_mean_absolute_error: 0.0312
#
# Epoch 00058: val_loss improved from 0.00258 to 0.00257, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 59/800
# 20/20 - 1s - loss: 0.0178 - mean_absolute_error: 0.0771 - val_loss: 0.0025 - val_mean_absolute_error: 0.0306
#
# Epoch 00059: val_loss improved from 0.00257 to 0.00245, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 60/800
# 20/20 - 1s - loss: 0.0174 - mean_absolute_error: 0.0764 - val_loss: 0.0026 - val_mean_absolute_error: 0.0308
#
# Epoch 00060: val_loss did not improve from 0.00245
# Learning rate: 0.0010
# Epoch 61/800
# 20/20 - 1s - loss: 0.0172 - mean_absolute_error: 0.0759 - val_loss: 0.0023 - val_mean_absolute_error: 0.0291
#
# Epoch 00061: val_loss improved from 0.00245 to 0.00229, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 62/800
# 20/20 - 1s - loss: 0.0170 - mean_absolute_error: 0.0753 - val_loss: 0.0031 - val_mean_absolute_error: 0.0324
#
# Epoch 00062: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 63/800
# 20/20 - 1s - loss: 0.0170 - mean_absolute_error: 0.0751 - val_loss: 0.0028 - val_mean_absolute_error: 0.0314
#
# Epoch 00063: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 64/800
# 20/20 - 1s - loss: 0.0169 - mean_absolute_error: 0.0749 - val_loss: 0.0039 - val_mean_absolute_error: 0.0361
#
# Epoch 00064: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 65/800
# 20/20 - 2s - loss: 0.0169 - mean_absolute_error: 0.0748 - val_loss: 0.0023 - val_mean_absolute_error: 0.0291
#
# Epoch 00065: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 66/800
# 20/20 - 1s - loss: 0.0164 - mean_absolute_error: 0.0738 - val_loss: 0.0025 - val_mean_absolute_error: 0.0307
#
# Epoch 00066: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 67/800
# 20/20 - 2s - loss: 0.0162 - mean_absolute_error: 0.0735 - val_loss: 0.0028 - val_mean_absolute_error: 0.0312
#
# Epoch 00067: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 68/800
# 20/20 - 1s - loss: 0.0162 - mean_absolute_error: 0.0733 - val_loss: 0.0031 - val_mean_absolute_error: 0.0320
#
# Epoch 00068: val_loss did not improve from 0.00229
# Learning rate: 0.0010
# Epoch 69/800
# 20/20 - 1s - loss: 0.0162 - mean_absolute_error: 0.0732 - val_loss: 0.0021 - val_mean_absolute_error: 0.0289
#
# Epoch 00069: val_loss improved from 0.00229 to 0.00214, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 70/800
# 20/20 - 1s - loss: 0.0158 - mean_absolute_error: 0.0721 - val_loss: 0.0020 - val_mean_absolute_error: 0.0288
#
# Epoch 00070: val_loss improved from 0.00214 to 0.00199, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 71/800
# 20/20 - 1s - loss: 0.0158 - mean_absolute_error: 0.0724 - val_loss: 0.0029 - val_mean_absolute_error: 0.0313
#
# Epoch 00071: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 72/800
# 20/20 - 1s - loss: 0.0156 - mean_absolute_error: 0.0719 - val_loss: 0.0025 - val_mean_absolute_error: 0.0300
#
# Epoch 00072: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 73/800
# 20/20 - 1s - loss: 0.0155 - mean_absolute_error: 0.0714 - val_loss: 0.0023 - val_mean_absolute_error: 0.0290
#
# Epoch 00073: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 74/800
# 20/20 - 1s - loss: 0.0153 - mean_absolute_error: 0.0710 - val_loss: 0.0026 - val_mean_absolute_error: 0.0297
#
# Epoch 00074: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 75/800
# 20/20 - 1s - loss: 0.0152 - mean_absolute_error: 0.0709 - val_loss: 0.0023 - val_mean_absolute_error: 0.0286
#
# Epoch 00075: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 76/800
# 20/20 - 1s - loss: 0.0151 - mean_absolute_error: 0.0706 - val_loss: 0.0021 - val_mean_absolute_error: 0.0284
#
# Epoch 00076: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 77/800
# 20/20 - 1s - loss: 0.0150 - mean_absolute_error: 0.0703 - val_loss: 0.0023 - val_mean_absolute_error: 0.0291
#
# Epoch 00077: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 78/800
# 20/20 - 1s - loss: 0.0149 - mean_absolute_error: 0.0701 - val_loss: 0.0021 - val_mean_absolute_error: 0.0278
#
# Epoch 00078: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 79/800
# 20/20 - 1s - loss: 0.0149 - mean_absolute_error: 0.0703 - val_loss: 0.0022 - val_mean_absolute_error: 0.0298
#
# Epoch 00079: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 80/800
# 20/20 - 1s - loss: 0.0151 - mean_absolute_error: 0.0703 - val_loss: 0.0028 - val_mean_absolute_error: 0.0321
#
# Epoch 00080: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 81/800
# 20/20 - 1s - loss: 0.0151 - mean_absolute_error: 0.0703 - val_loss: 0.0024 - val_mean_absolute_error: 0.0290
#
# Epoch 00081: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 82/800
# 20/20 - 1s - loss: 0.0149 - mean_absolute_error: 0.0701 - val_loss: 0.0023 - val_mean_absolute_error: 0.0291
#
# Epoch 00082: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 83/800
# 20/20 - 1s - loss: 0.0148 - mean_absolute_error: 0.0696 - val_loss: 0.0020 - val_mean_absolute_error: 0.0279
#
# Epoch 00083: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 84/800
# 20/20 - 1s - loss: 0.0147 - mean_absolute_error: 0.0695 - val_loss: 0.0022 - val_mean_absolute_error: 0.0292
#
# Epoch 00084: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 85/800
# 20/20 - 1s - loss: 0.0146 - mean_absolute_error: 0.0693 - val_loss: 0.0022 - val_mean_absolute_error: 0.0287
#
# Epoch 00085: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 86/800
# 20/20 - 1s - loss: 0.0145 - mean_absolute_error: 0.0689 - val_loss: 0.0021 - val_mean_absolute_error: 0.0285
#
# Epoch 00086: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 87/800
# 20/20 - 1s - loss: 0.0143 - mean_absolute_error: 0.0685 - val_loss: 0.0020 - val_mean_absolute_error: 0.0284
#
# Epoch 00087: val_loss improved from 0.00199 to 0.00199, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 88/800
# 20/20 - 1s - loss: 0.0143 - mean_absolute_error: 0.0682 - val_loss: 0.0024 - val_mean_absolute_error: 0.0293
#
# Epoch 00088: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 89/800
# 20/20 - 2s - loss: 0.0143 - mean_absolute_error: 0.0684 - val_loss: 0.0029 - val_mean_absolute_error: 0.0307
#
# Epoch 00089: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 90/800
# 20/20 - 1s - loss: 0.0142 - mean_absolute_error: 0.0680 - val_loss: 0.0027 - val_mean_absolute_error: 0.0295
#
# Epoch 00090: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 91/800
# 20/20 - 1s - loss: 0.0142 - mean_absolute_error: 0.0681 - val_loss: 0.0027 - val_mean_absolute_error: 0.0317
#
# Epoch 00091: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 92/800
# 20/20 - 2s - loss: 0.0142 - mean_absolute_error: 0.0679 - val_loss: 0.0022 - val_mean_absolute_error: 0.0283
#
# Epoch 00092: val_loss did not improve from 0.00199
# Learning rate: 0.0010
# Epoch 93/800
# 20/20 - 2s - loss: 0.0141 - mean_absolute_error: 0.0676 - val_loss: 0.0020 - val_mean_absolute_error: 0.0276
#
# Epoch 00093: val_loss improved from 0.00199 to 0.00197, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 94/800
# 20/20 - 1s - loss: 0.0140 - mean_absolute_error: 0.0676 - val_loss: 0.0022 - val_mean_absolute_error: 0.0282
#
# Epoch 00094: val_loss did not improve from 0.00197
# Learning rate: 0.0010
# Epoch 95/800
# 20/20 - 1s - loss: 0.0140 - mean_absolute_error: 0.0675 - val_loss: 0.0024 - val_mean_absolute_error: 0.0291
#
# Epoch 00095: val_loss did not improve from 0.00197
# Learning rate: 0.0010
# Epoch 96/800
# 20/20 - 1s - loss: 0.0140 - mean_absolute_error: 0.0676 - val_loss: 0.0021 - val_mean_absolute_error: 0.0282
#
# Epoch 00096: val_loss did not improve from 0.00197
# Learning rate: 0.0010
# Epoch 97/800
# 20/20 - 2s - loss: 0.0140 - mean_absolute_error: 0.0673 - val_loss: 0.0020 - val_mean_absolute_error: 0.0273
#
# Epoch 00097: val_loss did not improve from 0.00197
# Learning rate: 0.0010
# Epoch 98/800
# 20/20 - 1s - loss: 0.0139 - mean_absolute_error: 0.0671 - val_loss: 0.0024 - val_mean_absolute_error: 0.0284
#
# Epoch 00098: val_loss did not improve from 0.00197
# Learning rate: 0.0010
# Epoch 99/800
# 20/20 - 1s - loss: 0.0139 - mean_absolute_error: 0.0675 - val_loss: 0.0027 - val_mean_absolute_error: 0.0302
#
# Epoch 00099: val_loss did not improve from 0.00197
# Learning rate: 0.0010
# Epoch 100/800
# 20/20 - 1s - loss: 0.0139 - mean_absolute_error: 0.0671 - val_loss: 0.0018 - val_mean_absolute_error: 0.0266
#
# Epoch 00100: val_loss improved from 0.00197 to 0.00183, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 101/800
# 20/20 - 2s - loss: 0.0138 - mean_absolute_error: 0.0670 - val_loss: 0.0023 - val_mean_absolute_error: 0.0294
#
# Epoch 00101: val_loss did not improve from 0.00183
# Learning rate: 0.0010
# Epoch 102/800
# 20/20 - 1s - loss: 0.0139 - mean_absolute_error: 0.0671 - val_loss: 0.0021 - val_mean_absolute_error: 0.0288
#
# Epoch 00102: val_loss did not improve from 0.00183
# Learning rate: 0.0010
# Epoch 103/800
# 20/20 - 1s - loss: 0.0139 - mean_absolute_error: 0.0668 - val_loss: 0.0024 - val_mean_absolute_error: 0.0286
#
# Epoch 00103: val_loss did not improve from 0.00183
# Learning rate: 0.0010
# Epoch 104/800
# 20/20 - 1s - loss: 0.0138 - mean_absolute_error: 0.0669 - val_loss: 0.0018 - val_mean_absolute_error: 0.0262
#
# Epoch 00104: val_loss improved from 0.00183 to 0.00182, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 105/800
# 20/20 - 78s - loss: 0.0138 - mean_absolute_error: 0.0668 - val_loss: 0.0021 - val_mean_absolute_error: 0.0275
#
# Epoch 00105: val_loss did not improve from 0.00182
# Learning rate: 0.0010
# Epoch 106/800
# 20/20 - 2s - loss: 0.0136 - mean_absolute_error: 0.0664 - val_loss: 0.0019 - val_mean_absolute_error: 0.0268
#
# Epoch 00106: val_loss did not improve from 0.00182
# Learning rate: 0.0010
# Epoch 107/800
# 20/20 - 1s - loss: 0.0136 - mean_absolute_error: 0.0662 - val_loss: 0.0020 - val_mean_absolute_error: 0.0272
#
# Epoch 00107: val_loss did not improve from 0.00182
# Learning rate: 0.0010
# Epoch 108/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0661 - val_loss: 0.0018 - val_mean_absolute_error: 0.0270
#
# Epoch 00108: val_loss improved from 0.00182 to 0.00180, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 109/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0661 - val_loss: 0.0027 - val_mean_absolute_error: 0.0296
#
# Epoch 00109: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 110/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0661 - val_loss: 0.0019 - val_mean_absolute_error: 0.0272
#
# Epoch 00110: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 111/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0659 - val_loss: 0.0018 - val_mean_absolute_error: 0.0263
#
# Epoch 00111: val_loss improved from 0.00180 to 0.00180, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 112/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0661 - val_loss: 0.0019 - val_mean_absolute_error: 0.0260
#
# Epoch 00112: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 113/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0658 - val_loss: 0.0022 - val_mean_absolute_error: 0.0287
#
# Epoch 00113: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 114/800
# 20/20 - 1s - loss: 0.0134 - mean_absolute_error: 0.0660 - val_loss: 0.0019 - val_mean_absolute_error: 0.0265
#
# Epoch 00114: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 115/800
# 20/20 - 1s - loss: 0.0135 - mean_absolute_error: 0.0659 - val_loss: 0.0021 - val_mean_absolute_error: 0.0282
#
# Epoch 00115: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 116/800
# 20/20 - 1s - loss: 0.0134 - mean_absolute_error: 0.0658 - val_loss: 0.0020 - val_mean_absolute_error: 0.0278
#
# Epoch 00116: val_loss did not improve from 0.00180
# Learning rate: 0.0010
# Epoch 117/800
# 20/20 - 1s - loss: 0.0133 - mean_absolute_error: 0.0656 - val_loss: 0.0017 - val_mean_absolute_error: 0.0258
#
# Epoch 00117: val_loss improved from 0.00180 to 0.00173, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 118/800
# 20/20 - 1s - loss: 0.0133 - mean_absolute_error: 0.0655 - val_loss: 0.0017 - val_mean_absolute_error: 0.0251
#
# Epoch 00118: val_loss improved from 0.00173 to 0.00167, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 119/800
# 20/20 - 1s - loss: 0.0133 - mean_absolute_error: 0.0655 - val_loss: 0.0021 - val_mean_absolute_error: 0.0280
#
# Epoch 00119: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 120/800
# 20/20 - 1s - loss: 0.0134 - mean_absolute_error: 0.0657 - val_loss: 0.0023 - val_mean_absolute_error: 0.0286
#
# Epoch 00120: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 121/800
# 20/20 - 1s - loss: 0.0133 - mean_absolute_error: 0.0653 - val_loss: 0.0018 - val_mean_absolute_error: 0.0260
#
# Epoch 00121: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 122/800
# 20/20 - 2s - loss: 0.0132 - mean_absolute_error: 0.0652 - val_loss: 0.0021 - val_mean_absolute_error: 0.0289
#
# Epoch 00122: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 123/800
# 20/20 - 1s - loss: 0.0132 - mean_absolute_error: 0.0653 - val_loss: 0.0023 - val_mean_absolute_error: 0.0288
#
# Epoch 00123: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 124/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0652 - val_loss: 0.0018 - val_mean_absolute_error: 0.0267
#
# Epoch 00124: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 125/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0648 - val_loss: 0.0021 - val_mean_absolute_error: 0.0275
#
# Epoch 00125: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 126/800
# 20/20 - 1s - loss: 0.0132 - mean_absolute_error: 0.0650 - val_loss: 0.0020 - val_mean_absolute_error: 0.0272
#
# Epoch 00126: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 127/800
# 20/20 - 1s - loss: 0.0132 - mean_absolute_error: 0.0650 - val_loss: 0.0021 - val_mean_absolute_error: 0.0277
#
# Epoch 00127: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 128/800
# 20/20 - 1s - loss: 0.0130 - mean_absolute_error: 0.0648 - val_loss: 0.0018 - val_mean_absolute_error: 0.0263
#
# Epoch 00128: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 129/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0649 - val_loss: 0.0026 - val_mean_absolute_error: 0.0304
#
# Epoch 00129: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 130/800
# 20/20 - 1s - loss: 0.0132 - mean_absolute_error: 0.0651 - val_loss: 0.0020 - val_mean_absolute_error: 0.0273
#
# Epoch 00130: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 131/800
# 20/20 - 1s - loss: 0.0132 - mean_absolute_error: 0.0648 - val_loss: 0.0017 - val_mean_absolute_error: 0.0257
#
# Epoch 00131: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 132/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0647 - val_loss: 0.0023 - val_mean_absolute_error: 0.0282
#
# Epoch 00132: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 133/800
# 20/20 - 1s - loss: 0.0130 - mean_absolute_error: 0.0648 - val_loss: 0.0018 - val_mean_absolute_error: 0.0268
#
# Epoch 00133: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 134/800
# 20/20 - 1s - loss: 0.0130 - mean_absolute_error: 0.0646 - val_loss: 0.0019 - val_mean_absolute_error: 0.0273
#
# Epoch 00134: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 135/800
# 20/20 - 1s - loss: 0.0129 - mean_absolute_error: 0.0645 - val_loss: 0.0018 - val_mean_absolute_error: 0.0268
#
# Epoch 00135: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 136/800
# 20/20 - 1s - loss: 0.0129 - mean_absolute_error: 0.0645 - val_loss: 0.0018 - val_mean_absolute_error: 0.0268
#
# Epoch 00136: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 137/800
# 20/20 - 1s - loss: 0.0130 - mean_absolute_error: 0.0648 - val_loss: 0.0022 - val_mean_absolute_error: 0.0286
#
# Epoch 00137: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 138/800
# 20/20 - 1s - loss: 0.0130 - mean_absolute_error: 0.0644 - val_loss: 0.0019 - val_mean_absolute_error: 0.0272
#
# Epoch 00138: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 139/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0648 - val_loss: 0.0024 - val_mean_absolute_error: 0.0299
#
# Epoch 00139: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 140/800
# 20/20 - 1s - loss: 0.0134 - mean_absolute_error: 0.0653 - val_loss: 0.0020 - val_mean_absolute_error: 0.0281
#
# Epoch 00140: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 141/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0646 - val_loss: 0.0023 - val_mean_absolute_error: 0.0289
#
# Epoch 00141: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 142/800
# 20/20 - 1s - loss: 0.0131 - mean_absolute_error: 0.0645 - val_loss: 0.0018 - val_mean_absolute_error: 0.0261
#
# Epoch 00142: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 143/800
# 20/20 - 1s - loss: 0.0128 - mean_absolute_error: 0.0641 - val_loss: 0.0017 - val_mean_absolute_error: 0.0261
#
# Epoch 00143: val_loss improved from 0.00167 to 0.00167, saving model to D:/DeepSSFP\block_phantom_T2maps_syntheticbanding_2.keras
# Learning rate: 0.0010
# Epoch 144/800
# 20/20 - 1s - loss: 0.0129 - mean_absolute_error: 0.0642 - val_loss: 0.0021 - val_mean_absolute_error: 0.0290
#
# Epoch 00144: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 145/800
# 20/20 - 1s - loss: 0.0128 - mean_absolute_error: 0.0640 - val_loss: 0.0020 - val_mean_absolute_error: 0.0276
#
# Epoch 00145: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 146/800
# 20/20 - 1s - loss: 0.0128 - mean_absolute_error: 0.0640 - val_loss: 0.0018 - val_mean_absolute_error: 0.0267
#
# Epoch 00146: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 147/800
# 20/20 - 1s - loss: 0.0127 - mean_absolute_error: 0.0637 - val_loss: 0.0019 - val_mean_absolute_error: 0.0275
#
# Epoch 00147: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 148/800
# 20/20 - 1s - loss: 0.0127 - mean_absolute_error: 0.0636 - val_loss: 0.0020 - val_mean_absolute_error: 0.0280
#
# Epoch 00148: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 149/800
# 20/20 - 1s - loss: 0.0126 - mean_absolute_error: 0.0635 - val_loss: 0.0017 - val_mean_absolute_error: 0.0265
#
# Epoch 00149: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 150/800
# 20/20 - 1s - loss: 0.0127 - mean_absolute_error: 0.0636 - val_loss: 0.0021 - val_mean_absolute_error: 0.0283
#
# Epoch 00150: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 151/800
# 20/20 - 1s - loss: 0.0127 - mean_absolute_error: 0.0637 - val_loss: 0.0018 - val_mean_absolute_error: 0.0264
#
# Epoch 00151: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 152/800
# 20/20 - 1s - loss: 0.0127 - mean_absolute_error: 0.0636 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
#
# Epoch 00152: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 153/800
# 20/20 - 1s - loss: 0.0127 - mean_absolute_error: 0.0637 - val_loss: 0.0022 - val_mean_absolute_error: 0.0290
#
# Epoch 00153: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 154/800
# 20/20 - 1s - loss: 0.0126 - mean_absolute_error: 0.0633 - val_loss: 0.0024 - val_mean_absolute_error: 0.0286
#
# Epoch 00154: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 155/800
# 20/20 - 1s - loss: 0.0126 - mean_absolute_error: 0.0634 - val_loss: 0.0022 - val_mean_absolute_error: 0.0281
#
# Epoch 00155: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 156/800
# 20/20 - 1s - loss: 0.0125 - mean_absolute_error: 0.0633 - val_loss: 0.0020 - val_mean_absolute_error: 0.0274
#
# Epoch 00156: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 157/800
# 20/20 - 1s - loss: 0.0125 - mean_absolute_error: 0.0634 - val_loss: 0.0020 - val_mean_absolute_error: 0.0288
#
# Epoch 00157: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 158/800
# 20/20 - 1s - loss: 0.0125 - mean_absolute_error: 0.0630 - val_loss: 0.0020 - val_mean_absolute_error: 0.0271
#
# Epoch 00158: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 159/800
# 20/20 - 1s - loss: 0.0125 - mean_absolute_error: 0.0629 - val_loss: 0.0018 - val_mean_absolute_error: 0.0265
#
# Epoch 00159: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 160/800
# 20/20 - 1s - loss: 0.0124 - mean_absolute_error: 0.0633 - val_loss: 0.0019 - val_mean_absolute_error: 0.0273
#
# Epoch 00160: val_loss did not improve from 0.00167
# Learning rate: 0.0010
# Epoch 161/800
# 20/20 - 1s - loss: 0.0125 - mean_absolute_error: 0.0629 - val_loss: 0.0019 - val_mean_absolute_error: 0.0272
#
# Epoch 00161: val_loss did not improve from 0.00167
# Learning rate: 0.0010
#
# Epoch 00161: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 162/800
# 20/20 - 1s - loss: 0.0124 - mean_absolute_error: 0.0627 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
#
# Epoch 00162: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 163/800
# 20/20 - 1s - loss: 0.0123 - mean_absolute_error: 0.0626 - val_loss: 0.0020 - val_mean_absolute_error: 0.0276
#
# Epoch 00163: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 164/800
# 20/20 - 1s - loss: 0.0123 - mean_absolute_error: 0.0626 - val_loss: 0.0021 - val_mean_absolute_error: 0.0276
#
# Epoch 00164: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 165/800
# 20/20 - 1s - loss: 0.0123 - mean_absolute_error: 0.0626 - val_loss: 0.0019 - val_mean_absolute_error: 0.0268
#
# Epoch 00165: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 166/800
# 20/20 - 1s - loss: 0.0123 - mean_absolute_error: 0.0625 - val_loss: 0.0020 - val_mean_absolute_error: 0.0278
#
# Epoch 00166: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 167/800
# ...
#
# Epoch 00195: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 196/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0619 - val_loss: 0.0017 - val_mean_absolute_error: 0.0267
#
# Epoch 00196: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 197/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0618 - val_loss: 0.0017 - val_mean_absolute_error: 0.0267
#
# Epoch 00197: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 198/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0621 - val_loss: 0.0019 - val_mean_absolute_error: 0.0276
#
# Epoch 00198: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 199/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0618 - val_loss: 0.0020 - val_mean_absolute_error: 0.0277
#
# Epoch 00199: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 200/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0618 - val_loss: 0.0018 - val_mean_absolute_error: 0.0274
#
# Epoch 00200: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 201/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0617 - val_loss: 0.0021 - val_mean_absolute_error: 0.0285
#
# Epoch 00201: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 202/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0618 - val_loss: 0.0020 - val_mean_absolute_error: 0.0280
#
# Epoch 00202: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 203/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0617 - val_loss: 0.0020 - val_mean_absolute_error: 0.0279
#
# Epoch 00203: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 204/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0619 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278
#
# Epoch 00204: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 205/800
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0617 - val_loss: 0.0020 - val_mean_absolute_error: 0.0282
#
# Epoch 00205: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 206/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0617 - val_loss: 0.0020 - val_mean_absolute_error: 0.0283
#
# Epoch 00206: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 207/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0616 - val_loss: 0.0020 - val_mean_absolute_error: 0.0283
#
# Epoch 00207: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 208/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0616 - val_loss: 0.0020 - val_mean_absolute_error: 0.0282
#
# Epoch 00208: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 209/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0615 - val_loss: 0.0018 - val_mean_absolute_error: 0.0272
#
# Epoch 00209: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 210/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0615 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
#
# Epoch 00210: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 211/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0616 - val_loss: 0.0021 - val_mean_absolute_error: 0.0291
#
# Epoch 00211: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 212/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0615 - val_loss: 0.0020 - val_mean_absolute_error: 0.0286
#
# Epoch 00212: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 213/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0616 - val_loss: 0.0020 - val_mean_absolute_error: 0.0286
#
# Epoch 00213: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 214/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0614 - val_loss: 0.0023 - val_mean_absolute_error: 0.0293
#
# Epoch 00214: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 215/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0616 - val_loss: 0.0019 - val_mean_absolute_error: 0.0277
#
# Epoch 00215: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 216/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0613 - val_loss: 0.0019 - val_mean_absolute_error: 0.0283
#
# Epoch 00216: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 217/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0614 - val_loss: 0.0020 - val_mean_absolute_error: 0.0281
#
# Epoch 00217: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 218/800
# 20/20 - 1s - loss: 0.0120 - mean_absolute_error: 0.0614 - val_loss: 0.0019 - val_mean_absolute_error: 0.0281
#
# Epoch 00218: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 219/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0613 - val_loss: 0.0020 - val_mean_absolute_error: 0.0285
#
# Epoch 00219: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 220/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0612 - val_loss: 0.0023 - val_mean_absolute_error: 0.0293
#
# Epoch 00220: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 221/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0613 - val_loss: 0.0020 - val_mean_absolute_error: 0.0280
#
# Epoch 00221: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 222/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0612 - val_loss: 0.0020 - val_mean_absolute_error: 0.0279
#
# Epoch 00222: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 223/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0611 - val_loss: 0.0019 - val_mean_absolute_error: 0.0276
#
# Epoch 00223: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 224/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0611 - val_loss: 0.0018 - val_mean_absolute_error: 0.0273
#
# Epoch 00224: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 225/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0610 - val_loss: 0.0020 - val_mean_absolute_error: 0.0281
#
# Epoch 00225: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 226/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0610 - val_loss: 0.0020 - val_mean_absolute_error: 0.0281
#
# Epoch 00226: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 227/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0611 - val_loss: 0.0022 - val_mean_absolute_error: 0.0288
#
# Epoch 00227: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 228/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0610 - val_loss: 0.0020 - val_mean_absolute_error: 0.0287
#
# Epoch 00228: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 229/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0609 - val_loss: 0.0020 - val_mean_absolute_error: 0.0282
#
# Epoch 00229: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 230/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0610 - val_loss: 0.0021 - val_mean_absolute_error: 0.0288
#
# Epoch 00230: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 231/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0609 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278
#
# Epoch 00231: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 232/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0610 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278
#
# Epoch 00232: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 233/800
# 20/20 - 1s - loss: 0.0119 - mean_absolute_error: 0.0611 - val_loss: 0.0020 - val_mean_absolute_error: 0.0277
#
# Epoch 00233: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 234/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0609 - val_loss: 0.0020 - val_mean_absolute_error: 0.0287
#
# Epoch 00234: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 235/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0608 - val_loss: 0.0019 - val_mean_absolute_error: 0.0282
#
# Epoch 00235: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 236/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0608 - val_loss: 0.0021 - val_mean_absolute_error: 0.0293
#
# Epoch 00236: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 237/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0608 - val_loss: 0.0021 - val_mean_absolute_error: 0.0289
#
# Epoch 00237: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 238/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0607 - val_loss: 0.0019 - val_mean_absolute_error: 0.0274
#
# Epoch 00238: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 239/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0609 - val_loss: 0.0020 - val_mean_absolute_error: 0.0278
#
# Epoch 00239: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 240/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0607 - val_loss: 0.0018 - val_mean_absolute_error: 0.0271
#
# Epoch 00240: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 241/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0608 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
#
# Epoch 00241: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 242/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0271
#
# Epoch 00242: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 243/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0608 - val_loss: 0.0020 - val_mean_absolute_error: 0.0280
#
# Epoch 00243: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 244/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0608 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
#
# Epoch 00244: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 245/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0607 - val_loss: 0.0021 - val_mean_absolute_error: 0.0286
#
# Epoch 00245: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 246/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0275
#
# Epoch 00246: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 247/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0277
#
# Epoch 00247: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 248/800
# 20/20 - 1s - loss: 0.0117 - mean_absolute_error: 0.0607 - val_loss: 0.0021 - val_mean_absolute_error: 0.0289
#
# Epoch 00248: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 249/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0607 - val_loss: 0.0021 - val_mean_absolute_error: 0.0288
#
# Epoch 00249: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 250/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0606 - val_loss: 0.0020 - val_mean_absolute_error: 0.0279
#
# Epoch 00250: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 251/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0606 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278
#
# Epoch 00251: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 252/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0606 - val_loss: 0.0020 - val_mean_absolute_error: 0.0279
#
# Epoch 00252: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 253/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0607 - val_loss: 0.0021 - val_mean_absolute_error: 0.0291
#
# Epoch 00253: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 254/800
# 20/20 - 1s - loss: 0.0117 - mean_absolute_error: 0.0605 - val_loss: 0.0020 - val_mean_absolute_error: 0.0283
#
# Epoch 00254: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 255/800
# 20/20 - 1s - loss: 0.0118 - mean_absolute_error: 0.0607 - val_loss: 0.0019 - val_mean_absolute_error: 0.0277
#
# Epoch 00255: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 256/800
# 20/20 - 1s - loss: 0.0117 - mean_absolute_error: 0.0605 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
#
# Epoch 00256: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 257/800
# 20/20 - 1s - loss: 0.0117 - mean_absolute_error: 0.0605 - val_loss: 0.0018 - val_mean_absolute_error: 0.0275
#
# Epoch 00257: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 258/800
# 20/20 - 1s - loss: 0.0116 - mean_absolute_error: 0.0603 - val_loss: 0.0019 - val_mean_absolute_error: 0.0280
#
# Epoch 00258: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 259/800
# 20/20 - 1s - loss: 0.0116 - mean_absolute_error: 0.0603 - val_loss: 0.0019 - val_mean_absolute_error: 0.0287
#
# Epoch 00259: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 260/800
# 20/20 - 1s - loss: 0.0116 - mean_absolute_error: 0.0603 - val_loss: 0.0018 - val_mean_absolute_error: 0.0274
#
# Epoch 00260: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Epoch 261/800
# 20/20 - 1s - loss: 0.0116 - mean_absolute_error: 0.0601 - val_loss: 0.0019 - val_mean_absolute_error: 0.0282
#
# Epoch 00261: val_loss did not improve from 0.00167
# Learning rate: 0.0005
# Restoring model weights from the end of the best epoch.
#
# Epoch 00261: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 00261: early stopping
# 2025-04-22 23:27:51,752 - DeepSSFP - INFO - Final model saved to D:/DeepSSFP/block_phantom_T2maps_syntheticbanding_2.keras
# 2/2 [==============================] - 1s 14ms/step - loss: 0.0023 - mean_absolute_error: 0.0291
# 2025-04-22 23:27:53,449 - DeepSSFP - INFO - Training Complete. Loss: 0.0023, MAE: 0.0291
# 2025-04-22 23:27:53,450 - DeepSSFP - INFO - Time Elapsed: 459.94 seconds
# 2025-04-22 23:27:54,608 - DeepSSFP - INFO - Training history plot saved to D:/DeepSSFP/block_phantom_T2maps_syntheticbanding_2_training_history.png
# 2025-04-22 23:27:55,028 - DeepSSFP - INFO - Making predictions on data with shape (40, 128, 128, 4)
# 2025-04-22 23:27:55,151 - DeepSSFP - INFO - Predictions complete. Output shape: (40, 128, 128, 12)
# Selected indices: [ 4 18]
# Figure size: (28, 4)
# Image visualization saved to D:/DeepSSFP/block_phantom_T2maps_syntheticbanding_2_prediction_results.png
# Target shape: (40, 128, 128, 6), Prediction shape: (40, 128, 128, 6)
# Evaluating band reduction...
# Target shape: (40, 128, 128, 6)
# Prediction shape: (40, 128, 128, 6)
# Segmentation shape: (128, 128)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 import deepssfp.analysis
# ----> 2 results = deepssfp.analysis.run_experiment(
#       3     mode=mode,
#       4     model_name=model_name,
#       5     model_dir=model_dir,
#       6     train_model=True,
#       7     custom_dataset=dataset
#       8 )
#
# File c:\Users\mmend\projects\mri\deep-ssfp-mri\deepssfp\analysis.py:250, in run_experiment(mode, model_name, model_dir, train_model, custom_dataset, ds, save_dataset)
#     248 # Run band reduction evaluation
#     249 print("\nEvaluating band reduction...")
# --> 250 band_metrics = deepssfp.evaluate_band_reduction(
#     251     target_complex,
#     252     pred_complex,
#     253     seg,
#     254     sort_values=False,
#     255     fig_size=(6, 2),
#     256     save_path=f"{path}_band_metrics"
#     257 )
#     259 # Calculate additional image quality metrics
#     260 print("\nCalculating image quality metrics...")
#
# File c:\Users\mmend\projects\mri\deep-ssfp-mri\deepssfp\metrics.py:241, in evaluate_band_reduction(target, prediction, seg, sort_values, fig_size, save_path)
#     239     pass
#     240 else:
# --> 241     raise ValueError(f"Error: Expected target/prediction with shape (samples, height, width): {target.shape} and seg with shape (height, width): {seg.shape}")
#     243 # Process the first sample for visualization
#     244 sample_idx = 0
#
# ValueError: Error: Expected target/prediction with shape (samples, height, width): (40, 128, 128, 6) and seg with shape (height, width): (128, 128)
