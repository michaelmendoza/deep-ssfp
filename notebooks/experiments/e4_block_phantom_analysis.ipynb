# %%
import os
import sys
sys.path.insert(0, '../..')
import numpy as np
import matplotlib.pyplot as plt
import mssfp
import deepssfp
import deepssfp.analysis

# %%
modes=['BandRemoval:4', 'BandRemoval:2', 'SuperFOV', 'SyntheticBanding']
model_dir = "D:/DeepSSFP/"
model_name="block9_phantom"

# %%
#results = deepssfp.analysis.run_experiment(mode=deepssfp.DataMode.SyntheticBanding.value, model_name=model_name, model_dir=model_dir, train_model=True )

# %%
deepssfp.analysis.run_all_experiments(
    modes=modes,
    model_name=model_name,
    model_dir=model_dir,
    train_models=True  # Set to False to use pre-trained models
)
# Out:
# ===== Running experiment: BandRemoval:4 =====
# Model path: D:/DeepSSFP/block9_phantom_bandremoval_4
# Dataset path: D:/DeepSSFP/block9_phantom_dataset.npy
# Saved dataset found. Loading from file: D:/DeepSSFP/block9_phantom_dataset.npy
# Data shape: (200, 128, 128, 4)
# Training data shape: (160, 128, 128, 8), (160, 128, 128, 2)
# Input scaler stats: mean=-0.0039, std=0.0676
# Output scaler stats: mean=-0.0045, std=0.0531
# Selected indices: [11 10 14]
# Figure size: (10, 6)
# 2025-03-24 19:24:32,368 - DeepSSFP - INFO - Model will be saved to: D:/DeepSSFP/block9_phantom_bandremoval_4
# 2025-03-24 19:24:32,376 - DeepSSFP - INFO - Training DataSet: (160, 128, 128, 8) | (160, 128, 128, 2)
# 2025-03-24 19:24:32,376 - DeepSSFP - INFO - Test DataSet: (40, 128, 128, 8) | (40, 128, 128, 2)
# Training model...
# 2025-03-24 19:24:33,377 - DeepSSFP - INFO - Loading existing model from D:/DeepSSFP/block9_phantom_bandremoval_4.keras
# ...

# %%
# Compare experiment results
deepssfp.analysis.compare_experiments(
    modes=modes,
    model_name=model_name,
    model_dir=model_dir
)
# Out:
# Comparison plots saved to D:/DeepSSFP/block9_phantom_comparison_plots
#
# ===== Experiment Comparison Summary =====
# Model: block9_phantom
# Modes: BandRemoval:4, BandRemoval:2, SuperFOV, SyntheticBanding
#
# Global Image Quality Metrics:
# Metric  BandRemoval:4  BandRemoval:2  SuperFOV  SyntheticBanding
#    MSE   3.279437e-07   3.978904e-07  0.000003      3.535204e-07
#    MAE   4.419308e-04   4.589799e-04  0.001084      4.153979e-04
#   PSNR   6.487432e+01   6.437392e+01 58.871100      6.456177e+01
#   SSIM   9.996151e-01   9.996098e-01  0.995268      9.997999e-01
#  NRMSE   7.578001e-03   8.149392e-03  0.018102      7.861741e-03
#
# Best Mode by Metric:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Compare experiment results
# ----> 2 deepssfp.analysis.compare_experiments(
#       3     modes=modes,
#       4     model_name=model_name,
# ...
