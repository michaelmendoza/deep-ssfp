# %%
import sys
sys.path.insert(0, '../')
import numpy as np
import matplotlib.pyplot as plt 
from deepssfp import dataloader, view, recon, dataset, dataformatter, deepssfp, models, plotlib

# %%
mode = 'SuperFOV'
model, history, ds, predictions = deepssfp.train(mode, epochs=50)
# Out:
# Training DataSet: (102, 128, 128, 4) (102, 128, 128, 4)
# Test DataSet: (26, 128, 128, 4) (26, 128, 128, 4)
# DL Model: 128, 128, 4, 4
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  img (InputLayer)               [(None, 128, 128, 4  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  1184        ['img[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d_1[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
# ...

# %%
plotlib.plot_model_history(history)

# %%
ds.x_test.shape, ds.y_test.shape, predictions.shape

# %%
for i in range(26):
    plotlib.plot_model_results(i, ds.x_test, ds.y_test, predictions, kspace=True)
