# %%
import sys
sys.path.insert(0, '../')
import numpy as np
import matplotlib.pyplot as plt 
from deepssfp import dataloader, view, recon, dataset, dataformatter, deepssfp, models, plotlib

# %%
mode = 'BandRemoval:2'
ds = dataset.Dataset(mode)
print(ds.x_train.shape, ds.y_train.shape)
plt.figure()
plt.subplot(1,1,1)
plt.imshow(np.abs(ds.y_train[0,:,:,0] + 1j * ds.y_train[0,:,:,1]))
plt.show()
# Out:
# (102, 128, 128, 4) (102, 128, 128, 2)

# %%
model, history, ds, predictions = deepssfp.train(mode, epochs=400)
# Out:
# Training DataSet: (102, 128, 128, 4) (102, 128, 128, 2)
# Test DataSet: (26, 128, 128, 4) (26, 128, 128, 2)
# DL Model: 128, 128, 4, 2
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 128, 128, 4) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 1184        img[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 256)  1179904     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_transpose[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 128)  295040      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 128)  512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   73792       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_2[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 32) 18464       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_3[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 2)  66          batch_normalization_8[0][0]
# ==================================================================================================
# Total params: 8,636,706
# Trainable params: 8,633,762
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# Epoch 1/400
# 20/20 - 13s - loss: 0.4868 - mean_absolute_error: 0.5249 - val_loss: 0.3943 - val_mean_absolute_error: 0.4435
#
# Epoch 00001: val_loss improved from inf to 0.39432, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 2/400
# 20/20 - 1s - loss: 0.1330 - mean_absolute_error: 0.3134 - val_loss: 0.0785 - val_mean_absolute_error: 0.2111
#
# Epoch 00002: val_loss improved from 0.39432 to 0.07854, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 3/400
# 20/20 - 1s - loss: 0.0687 - mean_absolute_error: 0.2154 - val_loss: 0.0413 - val_mean_absolute_error: 0.1509
#
# Epoch 00003: val_loss improved from 0.07854 to 0.04132, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 4/400
# 20/20 - 1s - loss: 0.0426 - mean_absolute_error: 0.1616 - val_loss: 0.0260 - val_mean_absolute_error: 0.1169
#
# Epoch 00004: val_loss improved from 0.04132 to 0.02604, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 5/400
# 20/20 - 1s - loss: 0.0297 - mean_absolute_error: 0.1318 - val_loss: 0.0216 - val_mean_absolute_error: 0.1072
#
# Epoch 00005: val_loss improved from 0.02604 to 0.02157, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 6/400
# 20/20 - 1s - loss: 0.0207 - mean_absolute_error: 0.1076 - val_loss: 0.0140 - val_mean_absolute_error: 0.0853
#
# Epoch 00006: val_loss improved from 0.02157 to 0.01404, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 7/400
# 20/20 - 1s - loss: 0.0164 - mean_absolute_error: 0.0953 - val_loss: 0.0112 - val_mean_absolute_error: 0.0743
#
# Epoch 00007: val_loss improved from 0.01404 to 0.01123, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 8/400
# 20/20 - 1s - loss: 0.0155 - mean_absolute_error: 0.0936 - val_loss: 0.0085 - val_mean_absolute_error: 0.0644
#
# Epoch 00008: val_loss improved from 0.01123 to 0.00850, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 9/400
# 20/20 - 1s - loss: 0.0143 - mean_absolute_error: 0.0896 - val_loss: 0.0098 - val_mean_absolute_error: 0.0685
#
# Epoch 00009: val_loss did not improve from 0.00850
# Epoch 10/400
# 20/20 - 1s - loss: 0.0149 - mean_absolute_error: 0.0932 - val_loss: 0.0078 - val_mean_absolute_error: 0.0607
#
# Epoch 00010: val_loss improved from 0.00850 to 0.00784, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 11/400
# 20/20 - 1s - loss: 0.0126 - mean_absolute_error: 0.0849 - val_loss: 0.0063 - val_mean_absolute_error: 0.0551
#
# Epoch 00011: val_loss improved from 0.00784 to 0.00630, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 12/400
# 20/20 - 1s - loss: 0.0124 - mean_absolute_error: 0.0855 - val_loss: 0.0057 - val_mean_absolute_error: 0.0529
#
# Epoch 00012: val_loss improved from 0.00630 to 0.00568, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 13/400
# 20/20 - 1s - loss: 0.0122 - mean_absolute_error: 0.0847 - val_loss: 0.0066 - val_mean_absolute_error: 0.0588
#
# Epoch 00013: val_loss did not improve from 0.00568
# Epoch 14/400
# 20/20 - 1s - loss: 0.0121 - mean_absolute_error: 0.0844 - val_loss: 0.0059 - val_mean_absolute_error: 0.0540
#
# Epoch 00014: val_loss did not improve from 0.00568
# Epoch 15/400
# 20/20 - 1s - loss: 0.0112 - mean_absolute_error: 0.0818 - val_loss: 0.0047 - val_mean_absolute_error: 0.0484
#
# Epoch 00015: val_loss improved from 0.00568 to 0.00469, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 16/400
# 20/20 - 1s - loss: 0.0109 - mean_absolute_error: 0.0808 - val_loss: 0.0040 - val_mean_absolute_error: 0.0441
#
# Epoch 00016: val_loss improved from 0.00469 to 0.00399, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 17/400
# 20/20 - 1s - loss: 0.0101 - mean_absolute_error: 0.0778 - val_loss: 0.0041 - val_mean_absolute_error: 0.0450
#
# Epoch 00017: val_loss did not improve from 0.00399
# Epoch 18/400
# 20/20 - 1s - loss: 0.0105 - mean_absolute_error: 0.0801 - val_loss: 0.0045 - val_mean_absolute_error: 0.0486
#
# Epoch 00018: val_loss did not improve from 0.00399
# Epoch 19/400
# 20/20 - 1s - loss: 0.0103 - mean_absolute_error: 0.0785 - val_loss: 0.0037 - val_mean_absolute_error: 0.0427
#
# Epoch 00019: val_loss improved from 0.00399 to 0.00371, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 20/400
# 20/20 - 1s - loss: 0.0098 - mean_absolute_error: 0.0774 - val_loss: 0.0040 - val_mean_absolute_error: 0.0458
#
# Epoch 00020: val_loss did not improve from 0.00371
# Epoch 21/400
# 20/20 - 1s - loss: 0.0103 - mean_absolute_error: 0.0797 - val_loss: 0.0035 - val_mean_absolute_error: 0.0416
#
# Epoch 00021: val_loss improved from 0.00371 to 0.00346, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 22/400
# 20/20 - 1s - loss: 0.0102 - mean_absolute_error: 0.0791 - val_loss: 0.0036 - val_mean_absolute_error: 0.0420
#
# Epoch 00022: val_loss did not improve from 0.00346
# Epoch 23/400
# 20/20 - 1s - loss: 0.0098 - mean_absolute_error: 0.0771 - val_loss: 0.0037 - val_mean_absolute_error: 0.0429
#
# Epoch 00023: val_loss did not improve from 0.00346
# Epoch 24/400
# 20/20 - 1s - loss: 0.0100 - mean_absolute_error: 0.0781 - val_loss: 0.0033 - val_mean_absolute_error: 0.0409
#
# Epoch 00024: val_loss improved from 0.00346 to 0.00331, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 25/400
# 20/20 - 1s - loss: 0.0098 - mean_absolute_error: 0.0768 - val_loss: 0.0036 - val_mean_absolute_error: 0.0437
#
# Epoch 00025: val_loss did not improve from 0.00331
# Epoch 26/400
# 20/20 - 1s - loss: 0.0094 - mean_absolute_error: 0.0760 - val_loss: 0.0038 - val_mean_absolute_error: 0.0441
#
# Epoch 00026: val_loss did not improve from 0.00331
# Epoch 27/400
# 20/20 - 1s - loss: 0.0103 - mean_absolute_error: 0.0798 - val_loss: 0.0027 - val_mean_absolute_error: 0.0374
#
# Epoch 00027: val_loss improved from 0.00331 to 0.00274, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 28/400
# 20/20 - 1s - loss: 0.0092 - mean_absolute_error: 0.0746 - val_loss: 0.0029 - val_mean_absolute_error: 0.0395
#
# Epoch 00028: val_loss did not improve from 0.00274
# Epoch 29/400
# 20/20 - 1s - loss: 0.0094 - mean_absolute_error: 0.0756 - val_loss: 0.0033 - val_mean_absolute_error: 0.0421
#
# Epoch 00029: val_loss did not improve from 0.00274
# Epoch 30/400
# 20/20 - 1s - loss: 0.0093 - mean_absolute_error: 0.0769 - val_loss: 0.0028 - val_mean_absolute_error: 0.0387
#
# Epoch 00030: val_loss did not improve from 0.00274
# Epoch 31/400
# 20/20 - 1s - loss: 0.0096 - mean_absolute_error: 0.0774 - val_loss: 0.0030 - val_mean_absolute_error: 0.0395
#
# Epoch 00031: val_loss did not improve from 0.00274
# Epoch 32/400
# 20/20 - 1s - loss: 0.0090 - mean_absolute_error: 0.0744 - val_loss: 0.0027 - val_mean_absolute_error: 0.0374
#
# Epoch 00032: val_loss improved from 0.00274 to 0.00268, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 33/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0727 - val_loss: 0.0022 - val_mean_absolute_error: 0.0340
#
# Epoch 00033: val_loss improved from 0.00268 to 0.00221, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 34/400
# 20/20 - 1s - loss: 0.0088 - mean_absolute_error: 0.0739 - val_loss: 0.0025 - val_mean_absolute_error: 0.0369
#
# Epoch 00034: val_loss did not improve from 0.00221
# Epoch 35/400
# 20/20 - 1s - loss: 0.0091 - mean_absolute_error: 0.0754 - val_loss: 0.0021 - val_mean_absolute_error: 0.0331
#
# Epoch 00035: val_loss improved from 0.00221 to 0.00215, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 36/400
# 20/20 - 1s - loss: 0.0090 - mean_absolute_error: 0.0756 - val_loss: 0.0023 - val_mean_absolute_error: 0.0350
#
# Epoch 00036: val_loss did not improve from 0.00215
# Epoch 37/400
# 20/20 - 1s - loss: 0.0082 - mean_absolute_error: 0.0716 - val_loss: 0.0025 - val_mean_absolute_error: 0.0364
#
# Epoch 00037: val_loss did not improve from 0.00215
# Epoch 38/400
# 20/20 - 1s - loss: 0.0093 - mean_absolute_error: 0.0757 - val_loss: 0.0021 - val_mean_absolute_error: 0.0331
#
# Epoch 00038: val_loss improved from 0.00215 to 0.00205, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 39/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0695 - val_loss: 0.0022 - val_mean_absolute_error: 0.0342
#
# Epoch 00039: val_loss did not improve from 0.00205
# Epoch 40/400
# 20/20 - 1s - loss: 0.0086 - mean_absolute_error: 0.0729 - val_loss: 0.0022 - val_mean_absolute_error: 0.0344
#
# Epoch 00040: val_loss did not improve from 0.00205
# Epoch 41/400
# 20/20 - 1s - loss: 0.0088 - mean_absolute_error: 0.0741 - val_loss: 0.0026 - val_mean_absolute_error: 0.0373
#
# Epoch 00041: val_loss did not improve from 0.00205
# Epoch 42/400
# 20/20 - 1s - loss: 0.0091 - mean_absolute_error: 0.0744 - val_loss: 0.0026 - val_mean_absolute_error: 0.0383
#
# Epoch 00042: val_loss did not improve from 0.00205
# Epoch 43/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0726 - val_loss: 0.0022 - val_mean_absolute_error: 0.0340
#
# Epoch 00043: val_loss did not improve from 0.00205
# Epoch 44/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0722 - val_loss: 0.0032 - val_mean_absolute_error: 0.0436
#
# Epoch 00044: val_loss did not improve from 0.00205
# Epoch 45/400
# 20/20 - 1s - loss: 0.0083 - mean_absolute_error: 0.0712 - val_loss: 0.0033 - val_mean_absolute_error: 0.0433
#
# Epoch 00045: val_loss did not improve from 0.00205
# Epoch 46/400
# 20/20 - 1s - loss: 0.0091 - mean_absolute_error: 0.0747 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
#
# Epoch 00046: val_loss did not improve from 0.00205
# Epoch 47/400
# 20/20 - 1s - loss: 0.0091 - mean_absolute_error: 0.0765 - val_loss: 0.0020 - val_mean_absolute_error: 0.0332
#
# Epoch 00047: val_loss improved from 0.00205 to 0.00203, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 48/400
# 20/20 - 1s - loss: 0.0089 - mean_absolute_error: 0.0752 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
#
# Epoch 00048: val_loss improved from 0.00203 to 0.00167, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 49/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0701 - val_loss: 0.0018 - val_mean_absolute_error: 0.0306
#
# Epoch 00049: val_loss did not improve from 0.00167
# Epoch 50/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0694 - val_loss: 0.0017 - val_mean_absolute_error: 0.0301
#
# Epoch 00050: val_loss did not improve from 0.00167
# Epoch 51/400
# 20/20 - 1s - loss: 0.0088 - mean_absolute_error: 0.0755 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
#
# Epoch 00051: val_loss did not improve from 0.00167
# Epoch 52/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0708 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304
#
# Epoch 00052: val_loss did not improve from 0.00167
# Epoch 53/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0674 - val_loss: 0.0020 - val_mean_absolute_error: 0.0333
#
# Epoch 00053: val_loss did not improve from 0.00167
# Epoch 54/400
# 20/20 - 1s - loss: 0.0082 - mean_absolute_error: 0.0727 - val_loss: 0.0019 - val_mean_absolute_error: 0.0324
#
# Epoch 00054: val_loss did not improve from 0.00167
# Epoch 55/400
# 20/20 - 1s - loss: 0.0096 - mean_absolute_error: 0.0778 - val_loss: 0.0025 - val_mean_absolute_error: 0.0373
#
# Epoch 00055: val_loss did not improve from 0.00167
# Epoch 56/400
# 20/20 - 1s - loss: 0.0088 - mean_absolute_error: 0.0733 - val_loss: 0.0023 - val_mean_absolute_error: 0.0348
#
# Epoch 00056: val_loss did not improve from 0.00167
# Epoch 57/400
# 20/20 - 1s - loss: 0.0088 - mean_absolute_error: 0.0748 - val_loss: 0.0037 - val_mean_absolute_error: 0.0421
#
# Epoch 00057: val_loss did not improve from 0.00167
# Epoch 58/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0681 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318
#
# Epoch 00058: val_loss did not improve from 0.00167
# Epoch 59/400
# 20/20 - 1s - loss: 0.0081 - mean_absolute_error: 0.0710 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
#
# Epoch 00059: val_loss improved from 0.00167 to 0.00151, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 60/400
# 20/20 - 1s - loss: 0.0081 - mean_absolute_error: 0.0721 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
#
# Epoch 00060: val_loss did not improve from 0.00151
# Epoch 61/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0738 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
#
# Epoch 00061: val_loss did not improve from 0.00151
# Epoch 62/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0685 - val_loss: 0.0014 - val_mean_absolute_error: 0.0273
#
# Epoch 00062: val_loss improved from 0.00151 to 0.00138, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 63/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0699 - val_loss: 0.0014 - val_mean_absolute_error: 0.0281
#
# Epoch 00063: val_loss did not improve from 0.00138
# Epoch 64/400
# 20/20 - 1s - loss: 0.0083 - mean_absolute_error: 0.0733 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
#
# Epoch 00064: val_loss did not improve from 0.00138
# Epoch 65/400
# 20/20 - 1s - loss: 0.0083 - mean_absolute_error: 0.0712 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
#
# Epoch 00065: val_loss did not improve from 0.00138
# Epoch 66/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0693 - val_loss: 0.0019 - val_mean_absolute_error: 0.0321
#
# Epoch 00066: val_loss did not improve from 0.00138
# Epoch 67/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0686 - val_loss: 0.0014 - val_mean_absolute_error: 0.0281
#
# Epoch 00067: val_loss did not improve from 0.00138
# Epoch 68/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0680 - val_loss: 0.0018 - val_mean_absolute_error: 0.0313
#
# Epoch 00068: val_loss did not improve from 0.00138
# Epoch 69/400
# 20/20 - 1s - loss: 0.0091 - mean_absolute_error: 0.0771 - val_loss: 0.0022 - val_mean_absolute_error: 0.0349
#
# Epoch 00069: val_loss did not improve from 0.00138
# Epoch 70/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0732 - val_loss: 0.0030 - val_mean_absolute_error: 0.0395
#
# Epoch 00070: val_loss did not improve from 0.00138
# Epoch 71/400
# 20/20 - 1s - loss: 0.0086 - mean_absolute_error: 0.0738 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
#
# Epoch 00071: val_loss did not improve from 0.00138
# Epoch 72/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0719 - val_loss: 0.0015 - val_mean_absolute_error: 0.0283
#
# Epoch 00072: val_loss did not improve from 0.00138
# Epoch 73/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0730 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
#
# Epoch 00073: val_loss improved from 0.00138 to 0.00127, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 74/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0639 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
#
# Epoch 00074: val_loss did not improve from 0.00127
# Epoch 75/400
# 20/20 - 1s - loss: 0.0084 - mean_absolute_error: 0.0732 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
#
# Epoch 00075: val_loss improved from 0.00127 to 0.00125, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 76/400
# 20/20 - 1s - loss: 0.0079 - mean_absolute_error: 0.0707 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
#
# Epoch 00076: val_loss did not improve from 0.00125
# Epoch 77/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0674 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
#
# Epoch 00077: val_loss did not improve from 0.00125
# Epoch 78/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0677 - val_loss: 0.0016 - val_mean_absolute_error: 0.0301
#
# Epoch 00078: val_loss did not improve from 0.00125
# Epoch 79/400
# 20/20 - 1s - loss: 0.0084 - mean_absolute_error: 0.0728 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
#
# Epoch 00079: val_loss did not improve from 0.00125
# Epoch 80/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0674 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
#
# Epoch 00080: val_loss did not improve from 0.00125
# Epoch 81/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0681 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
#
# Epoch 00081: val_loss improved from 0.00125 to 0.00115, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 82/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0673 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
#
# Epoch 00082: val_loss did not improve from 0.00115
# Epoch 83/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0696 - val_loss: 0.0012 - val_mean_absolute_error: 0.0257
#
# Epoch 00083: val_loss did not improve from 0.00115
# Epoch 84/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0702 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
#
# Epoch 00084: val_loss did not improve from 0.00115
# Epoch 85/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0709 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
#
# Epoch 00085: val_loss improved from 0.00115 to 0.00106, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 86/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0688 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
#
# Epoch 00086: val_loss improved from 0.00106 to 0.00105, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 87/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0637 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
#
# Epoch 00087: val_loss did not improve from 0.00105
# Epoch 88/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0738 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
#
# Epoch 00088: val_loss did not improve from 0.00105
# Epoch 89/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0656 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
#
# Epoch 00089: val_loss did not improve from 0.00105
# Epoch 90/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0712 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
#
# Epoch 00090: val_loss did not improve from 0.00105
# Epoch 91/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0661 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
#
# Epoch 00091: val_loss did not improve from 0.00105
# Epoch 92/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0654 - val_loss: 0.0010 - val_mean_absolute_error: 0.0236
#
# Epoch 00092: val_loss improved from 0.00105 to 0.00101, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 93/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0676 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
#
# Epoch 00093: val_loss did not improve from 0.00101
# Epoch 94/400
# 20/20 - 1s - loss: 0.0082 - mean_absolute_error: 0.0731 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
#
# Epoch 00094: val_loss did not improve from 0.00101
# Epoch 95/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0683 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
#
# Epoch 00095: val_loss did not improve from 0.00101
# Epoch 96/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0673 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
#
# Epoch 00096: val_loss did not improve from 0.00101
# Epoch 97/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0665 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
#
# Epoch 00097: val_loss did not improve from 0.00101
# Epoch 98/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0672 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
#
# Epoch 00098: val_loss did not improve from 0.00101
# Epoch 99/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0672 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
#
# Epoch 00099: val_loss did not improve from 0.00101
# Epoch 100/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0733 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
#
# Epoch 00100: val_loss did not improve from 0.00101
# Epoch 101/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0646 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
#
# Epoch 00101: val_loss did not improve from 0.00101
# Epoch 102/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0695 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
#
# Epoch 00102: val_loss did not improve from 0.00101
# Epoch 103/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0697 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
#
# Epoch 00103: val_loss did not improve from 0.00101
# Epoch 104/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0712 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
#
# Epoch 00104: val_loss did not improve from 0.00101
# Epoch 105/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0679 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
#
# Epoch 00105: val_loss did not improve from 0.00101
# Epoch 106/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0688 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
#
# Epoch 00106: val_loss did not improve from 0.00101
# Epoch 107/400
# 20/20 - 1s - loss: 0.0081 - mean_absolute_error: 0.0725 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
#
# Epoch 00107: val_loss did not improve from 0.00101
# Epoch 108/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0667 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
#
# Epoch 00108: val_loss did not improve from 0.00101
# Epoch 109/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0667 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
#
# Epoch 00109: val_loss did not improve from 0.00101
# Epoch 110/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0696 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
#
# Epoch 00110: val_loss did not improve from 0.00101
# Epoch 111/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0666 - val_loss: 0.0018 - val_mean_absolute_error: 0.0317
#
# Epoch 00111: val_loss did not improve from 0.00101
# Epoch 112/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0708 - val_loss: 0.0017 - val_mean_absolute_error: 0.0294
#
# Epoch 00112: val_loss did not improve from 0.00101
# Epoch 113/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0665 - val_loss: 9.9828e-04 - val_mean_absolute_error: 0.0239
#
# Epoch 00113: val_loss improved from 0.00101 to 0.00100, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 114/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0679 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
#
# Epoch 00114: val_loss did not improve from 0.00100
# Epoch 115/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0708 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
#
# Epoch 00115: val_loss did not improve from 0.00100
# Epoch 116/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0697 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
#
# Epoch 00116: val_loss did not improve from 0.00100
# Epoch 117/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0640 - val_loss: 9.6517e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00117: val_loss improved from 0.00100 to 0.00097, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 118/400
# 20/20 - 1s - loss: 0.0079 - mean_absolute_error: 0.0703 - val_loss: 9.1416e-04 - val_mean_absolute_error: 0.0228
#
# Epoch 00118: val_loss improved from 0.00097 to 0.00091, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 119/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0645 - val_loss: 9.5144e-04 - val_mean_absolute_error: 0.0232
#
# Epoch 00119: val_loss did not improve from 0.00091
# Epoch 120/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0683 - val_loss: 9.6225e-04 - val_mean_absolute_error: 0.0235
#
# Epoch 00120: val_loss did not improve from 0.00091
# Epoch 121/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0698 - val_loss: 8.9490e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00121: val_loss improved from 0.00091 to 0.00089, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 122/400
# 20/20 - 1s - loss: 0.0063 - mean_absolute_error: 0.0619 - val_loss: 9.0001e-04 - val_mean_absolute_error: 0.0227
#
# Epoch 00122: val_loss did not improve from 0.00089
# Epoch 123/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0720 - val_loss: 9.4476e-04 - val_mean_absolute_error: 0.0234
#
# Epoch 00123: val_loss did not improve from 0.00089
# Epoch 124/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0667 - val_loss: 8.5714e-04 - val_mean_absolute_error: 0.0220
#
# Epoch 00124: val_loss improved from 0.00089 to 0.00086, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 125/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0653 - val_loss: 8.5206e-04 - val_mean_absolute_error: 0.0221
#
# Epoch 00125: val_loss improved from 0.00086 to 0.00085, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 126/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0659 - val_loss: 9.0425e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00126: val_loss did not improve from 0.00085
# Epoch 127/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0677 - val_loss: 8.9650e-04 - val_mean_absolute_error: 0.0227
#
# Epoch 00127: val_loss did not improve from 0.00085
# Epoch 128/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0692 - val_loss: 9.1102e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00128: val_loss did not improve from 0.00085
# Epoch 129/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0636 - val_loss: 0.0010 - val_mean_absolute_error: 0.0239
#
# Epoch 00129: val_loss did not improve from 0.00085
# Epoch 130/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0667 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
#
# Epoch 00130: val_loss did not improve from 0.00085
# Epoch 131/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0723 - val_loss: 9.8089e-04 - val_mean_absolute_error: 0.0237
#
# Epoch 00131: val_loss did not improve from 0.00085
# Epoch 132/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0677 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
#
# Epoch 00132: val_loss did not improve from 0.00085
# Epoch 133/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0661 - val_loss: 9.8781e-04 - val_mean_absolute_error: 0.0239
#
# Epoch 00133: val_loss did not improve from 0.00085
# Epoch 134/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0656 - val_loss: 9.3782e-04 - val_mean_absolute_error: 0.0232
#
# Epoch 00134: val_loss did not improve from 0.00085
# Epoch 135/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0693 - val_loss: 9.7686e-04 - val_mean_absolute_error: 0.0238
#
# Epoch 00135: val_loss did not improve from 0.00085
# Epoch 136/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0667 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
#
# Epoch 00136: val_loss did not improve from 0.00085
# Epoch 137/400
# 20/20 - 1s - loss: 0.0087 - mean_absolute_error: 0.0743 - val_loss: 0.0018 - val_mean_absolute_error: 0.0313
#
# Epoch 00137: val_loss did not improve from 0.00085
# Epoch 138/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0682 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
#
# Epoch 00138: val_loss did not improve from 0.00085
# Epoch 139/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0699 - val_loss: 0.0014 - val_mean_absolute_error: 0.0286
#
# Epoch 00139: val_loss did not improve from 0.00085
# Epoch 140/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0696 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
#
# Epoch 00140: val_loss did not improve from 0.00085
# Epoch 141/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0735 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
#
# Epoch 00141: val_loss did not improve from 0.00085
# Epoch 142/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0669 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
#
# Epoch 00142: val_loss did not improve from 0.00085
# Epoch 143/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0684 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
#
# Epoch 00143: val_loss did not improve from 0.00085
# Epoch 144/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0698 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
#
# Epoch 00144: val_loss did not improve from 0.00085
# Epoch 145/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0676 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
#
# Epoch 00145: val_loss did not improve from 0.00085
# Epoch 146/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0696 - val_loss: 9.4147e-04 - val_mean_absolute_error: 0.0234
#
# Epoch 00146: val_loss did not improve from 0.00085
# Epoch 147/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0678 - val_loss: 9.0787e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00147: val_loss did not improve from 0.00085
# Epoch 148/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0691 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
#
# Epoch 00148: val_loss did not improve from 0.00085
# Epoch 149/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0708 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
#
# Epoch 00149: val_loss did not improve from 0.00085
# Epoch 150/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0640 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
#
# Epoch 00150: val_loss did not improve from 0.00085
# Epoch 151/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0706 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
#
# Epoch 00151: val_loss did not improve from 0.00085
# Epoch 152/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0681 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
#
# Epoch 00152: val_loss did not improve from 0.00085
# Epoch 153/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0654 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
#
# Epoch 00153: val_loss did not improve from 0.00085
# Epoch 154/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0711 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
#
# Epoch 00154: val_loss did not improve from 0.00085
# Epoch 155/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0684 - val_loss: 9.0299e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00155: val_loss did not improve from 0.00085
# Epoch 156/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0671 - val_loss: 8.8576e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00156: val_loss did not improve from 0.00085
# Epoch 157/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0657 - val_loss: 8.7126e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00157: val_loss did not improve from 0.00085
# Epoch 158/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0667 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
#
# Epoch 00158: val_loss did not improve from 0.00085
# Epoch 159/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0701 - val_loss: 0.0031 - val_mean_absolute_error: 0.0397
#
# Epoch 00159: val_loss did not improve from 0.00085
# Epoch 160/400
# 20/20 - 1s - loss: 0.0085 - mean_absolute_error: 0.0737 - val_loss: 0.0020 - val_mean_absolute_error: 0.0339
#
# Epoch 00160: val_loss did not improve from 0.00085
# Epoch 161/400
# 20/20 - 1s - loss: 0.0081 - mean_absolute_error: 0.0720 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
#
# Epoch 00161: val_loss did not improve from 0.00085
# Epoch 162/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0697 - val_loss: 0.0016 - val_mean_absolute_error: 0.0307
#
# Epoch 00162: val_loss did not improve from 0.00085
# Epoch 163/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0674 - val_loss: 9.8670e-04 - val_mean_absolute_error: 0.0237
#
# Epoch 00163: val_loss did not improve from 0.00085
# Epoch 164/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0666 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
#
# Epoch 00164: val_loss did not improve from 0.00085
# Epoch 165/400
# 20/20 - 1s - loss: 0.0067 - mean_absolute_error: 0.0654 - val_loss: 9.4616e-04 - val_mean_absolute_error: 0.0234
#
# Epoch 00165: val_loss did not improve from 0.00085
# Epoch 166/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0695 - val_loss: 8.2692e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00166: val_loss improved from 0.00085 to 0.00083, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 167/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0644 - val_loss: 7.6764e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00167: val_loss improved from 0.00083 to 0.00077, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 168/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0682 - val_loss: 7.7167e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00168: val_loss did not improve from 0.00077
# Epoch 169/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0655 - val_loss: 7.7412e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00169: val_loss did not improve from 0.00077
# Epoch 170/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0670 - val_loss: 7.2592e-04 - val_mean_absolute_error: 0.0204
#
# Epoch 00170: val_loss improved from 0.00077 to 0.00073, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 171/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0693 - val_loss: 8.0912e-04 - val_mean_absolute_error: 0.0217
#
# Epoch 00171: val_loss did not improve from 0.00073
# Epoch 172/400
# 20/20 - 1s - loss: 0.0063 - mean_absolute_error: 0.0624 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
#
# Epoch 00172: val_loss did not improve from 0.00073
# Epoch 173/400
# 20/20 - 1s - loss: 0.0079 - mean_absolute_error: 0.0716 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
#
# Epoch 00173: val_loss did not improve from 0.00073
# Epoch 174/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0688 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
#
# Epoch 00174: val_loss did not improve from 0.00073
# Epoch 175/400
# 20/20 - 1s - loss: 0.0081 - mean_absolute_error: 0.0706 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
#
# Epoch 00175: val_loss did not improve from 0.00073
# Epoch 176/400
# 20/20 - 1s - loss: 0.0088 - mean_absolute_error: 0.0727 - val_loss: 0.0034 - val_mean_absolute_error: 0.0462
#
# Epoch 00176: val_loss did not improve from 0.00073
# Epoch 177/400
# 20/20 - 1s - loss: 0.0092 - mean_absolute_error: 0.0752 - val_loss: 0.0036 - val_mean_absolute_error: 0.0454
#
# Epoch 00177: val_loss did not improve from 0.00073
# Epoch 178/400
# 20/20 - 1s - loss: 0.0098 - mean_absolute_error: 0.0787 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
#
# Epoch 00178: val_loss did not improve from 0.00073
# Epoch 179/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0675 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
#
# Epoch 00179: val_loss did not improve from 0.00073
# Epoch 180/400
# 20/20 - 1s - loss: 0.0081 - mean_absolute_error: 0.0712 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
#
# Epoch 00180: val_loss did not improve from 0.00073
# Epoch 181/400
# 20/20 - 1s - loss: 0.0064 - mean_absolute_error: 0.0637 - val_loss: 8.3974e-04 - val_mean_absolute_error: 0.0220
#
# Epoch 00181: val_loss did not improve from 0.00073
# Epoch 182/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0679 - val_loss: 8.5405e-04 - val_mean_absolute_error: 0.0224
#
# Epoch 00182: val_loss did not improve from 0.00073
# Epoch 183/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0663 - val_loss: 7.6926e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00183: val_loss did not improve from 0.00073
# Epoch 184/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0633 - val_loss: 7.3565e-04 - val_mean_absolute_error: 0.0206
#
# Epoch 00184: val_loss did not improve from 0.00073
# Epoch 185/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0659 - val_loss: 7.5225e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00185: val_loss did not improve from 0.00073
# Epoch 186/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0673 - val_loss: 7.1934e-04 - val_mean_absolute_error: 0.0205
#
# Epoch 00186: val_loss improved from 0.00073 to 0.00072, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 187/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0704 - val_loss: 8.3780e-04 - val_mean_absolute_error: 0.0223
#
# Epoch 00187: val_loss did not improve from 0.00072
# Epoch 188/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0679 - val_loss: 7.3067e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00188: val_loss did not improve from 0.00072
# Epoch 189/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0650 - val_loss: 7.5137e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00189: val_loss did not improve from 0.00072
# Epoch 190/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0688 - val_loss: 7.4054e-04 - val_mean_absolute_error: 0.0208
#
# Epoch 00190: val_loss did not improve from 0.00072
# Epoch 191/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0648 - val_loss: 6.9286e-04 - val_mean_absolute_error: 0.0200
#
# Epoch 00191: val_loss improved from 0.00072 to 0.00069, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 192/400
# 20/20 - 1s - loss: 0.0062 - mean_absolute_error: 0.0625 - val_loss: 7.3630e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00192: val_loss did not improve from 0.00069
# Epoch 193/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0670 - val_loss: 8.2321e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00193: val_loss did not improve from 0.00069
# Epoch 194/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0700 - val_loss: 8.9224e-04 - val_mean_absolute_error: 0.0228
#
# Epoch 00194: val_loss did not improve from 0.00069
# Epoch 195/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0657 - val_loss: 8.8598e-04 - val_mean_absolute_error: 0.0227
#
# Epoch 00195: val_loss did not improve from 0.00069
# Epoch 196/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0690 - val_loss: 0.0012 - val_mean_absolute_error: 0.0263
#
# Epoch 00196: val_loss did not improve from 0.00069
# Epoch 197/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0657 - val_loss: 8.8384e-04 - val_mean_absolute_error: 0.0226
#
# Epoch 00197: val_loss did not improve from 0.00069
# Epoch 198/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0669 - val_loss: 7.3316e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00198: val_loss did not improve from 0.00069
# Epoch 199/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0636 - val_loss: 9.0646e-04 - val_mean_absolute_error: 0.0232
#
# Epoch 00199: val_loss did not improve from 0.00069
# Epoch 200/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0716 - val_loss: 7.2819e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00200: val_loss did not improve from 0.00069
# Epoch 201/400
# 20/20 - 1s - loss: 0.0067 - mean_absolute_error: 0.0643 - val_loss: 7.8375e-04 - val_mean_absolute_error: 0.0214
#
# Epoch 00201: val_loss did not improve from 0.00069
# Epoch 202/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0707 - val_loss: 7.6376e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00202: val_loss did not improve from 0.00069
# Epoch 203/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0642 - val_loss: 8.3180e-04 - val_mean_absolute_error: 0.0221
#
# Epoch 00203: val_loss did not improve from 0.00069
# Epoch 204/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0648 - val_loss: 9.1357e-04 - val_mean_absolute_error: 0.0233
#
# Epoch 00204: val_loss did not improve from 0.00069
# Epoch 205/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0692 - val_loss: 8.8318e-04 - val_mean_absolute_error: 0.0227
#
# Epoch 00205: val_loss did not improve from 0.00069
# Epoch 206/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0679 - val_loss: 9.6845e-04 - val_mean_absolute_error: 0.0236
#
# Epoch 00206: val_loss did not improve from 0.00069
# Epoch 207/400
# 20/20 - 1s - loss: 0.0067 - mean_absolute_error: 0.0652 - val_loss: 9.8646e-04 - val_mean_absolute_error: 0.0241
#
# Epoch 00207: val_loss did not improve from 0.00069
# Epoch 208/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0699 - val_loss: 9.0269e-04 - val_mean_absolute_error: 0.0233
#
# ...
# Epoch 314/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0693 - val_loss: 8.9962e-04 - val_mean_absolute_error: 0.0231
#
# Epoch 00314: val_loss did not improve from 0.00063
# Epoch 315/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0667 - val_loss: 8.5411e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00315: val_loss did not improve from 0.00063
# Epoch 316/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0656 - val_loss: 7.2262e-04 - val_mean_absolute_error: 0.0207
#
# Epoch 00316: val_loss did not improve from 0.00063
# Epoch 317/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0659 - val_loss: 8.1438e-04 - val_mean_absolute_error: 0.0218
#
# Epoch 00317: val_loss did not improve from 0.00063
# Epoch 318/400
# 20/20 - 1s - loss: 0.0080 - mean_absolute_error: 0.0713 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
#
# Epoch 00318: val_loss did not improve from 0.00063
# Epoch 319/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0639 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
#
# Epoch 00319: val_loss did not improve from 0.00063
# Epoch 320/400
# 20/20 - 1s - loss: 0.0075 - mean_absolute_error: 0.0700 - val_loss: 9.2554e-04 - val_mean_absolute_error: 0.0232
#
# Epoch 00320: val_loss did not improve from 0.00063
# Epoch 321/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0658 - val_loss: 7.7201e-04 - val_mean_absolute_error: 0.0213
#
# Epoch 00321: val_loss did not improve from 0.00063
# Epoch 322/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0680 - val_loss: 7.0407e-04 - val_mean_absolute_error: 0.0204
#
# Epoch 00322: val_loss did not improve from 0.00063
# Epoch 323/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0656 - val_loss: 7.6634e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00323: val_loss did not improve from 0.00063
# Epoch 324/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0657 - val_loss: 6.9404e-04 - val_mean_absolute_error: 0.0202
#
# Epoch 00324: val_loss did not improve from 0.00063
# Epoch 325/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0669 - val_loss: 6.4911e-04 - val_mean_absolute_error: 0.0196
#
# Epoch 00325: val_loss did not improve from 0.00063
# Epoch 326/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0695 - val_loss: 6.0921e-04 - val_mean_absolute_error: 0.0189
#
# Epoch 00326: val_loss improved from 0.00063 to 0.00061, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 327/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0653 - val_loss: 6.3003e-04 - val_mean_absolute_error: 0.0193
#
# Epoch 00327: val_loss did not improve from 0.00061
# Epoch 328/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0669 - val_loss: 6.4314e-04 - val_mean_absolute_error: 0.0195
#
# Epoch 00328: val_loss did not improve from 0.00061
# Epoch 329/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0639 - val_loss: 6.7986e-04 - val_mean_absolute_error: 0.0201
#
# Epoch 00329: val_loss did not improve from 0.00061
# Epoch 330/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0686 - val_loss: 6.7640e-04 - val_mean_absolute_error: 0.0199
#
# Epoch 00330: val_loss did not improve from 0.00061
# Epoch 331/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0637 - val_loss: 6.8008e-04 - val_mean_absolute_error: 0.0201
#
# Epoch 00331: val_loss did not improve from 0.00061
# Epoch 332/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0697 - val_loss: 6.5914e-04 - val_mean_absolute_error: 0.0199
#
# Epoch 00332: val_loss did not improve from 0.00061
# Epoch 333/400
# 20/20 - 1s - loss: 0.0059 - mean_absolute_error: 0.0605 - val_loss: 6.2398e-04 - val_mean_absolute_error: 0.0192
#
# Epoch 00333: val_loss did not improve from 0.00061
# Epoch 334/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0707 - val_loss: 7.4831e-04 - val_mean_absolute_error: 0.0210
#
# Epoch 00334: val_loss did not improve from 0.00061
# Epoch 335/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0642 - val_loss: 9.7214e-04 - val_mean_absolute_error: 0.0236
#
# Epoch 00335: val_loss did not improve from 0.00061
# Epoch 336/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0681 - val_loss: 7.6967e-04 - val_mean_absolute_error: 0.0212
#
# Epoch 00336: val_loss did not improve from 0.00061
# Epoch 337/400
# 20/20 - 1s - loss: 0.0067 - mean_absolute_error: 0.0646 - val_loss: 9.3591e-04 - val_mean_absolute_error: 0.0233
#
# Epoch 00337: val_loss did not improve from 0.00061
# Epoch 338/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0682 - val_loss: 7.2425e-04 - val_mean_absolute_error: 0.0205
#
# Epoch 00338: val_loss did not improve from 0.00061
# Epoch 339/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0701 - val_loss: 9.0039e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00339: val_loss did not improve from 0.00061
# Epoch 340/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0638 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
#
# Epoch 00340: val_loss did not improve from 0.00061
# Epoch 341/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0679 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
#
# Epoch 00341: val_loss did not improve from 0.00061
# Epoch 342/400
# 20/20 - 1s - loss: 0.0082 - mean_absolute_error: 0.0712 - val_loss: 0.0019 - val_mean_absolute_error: 0.0330
#
# Epoch 00342: val_loss did not improve from 0.00061
# Epoch 343/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0682 - val_loss: 0.0028 - val_mean_absolute_error: 0.0409
#
# Epoch 00343: val_loss did not improve from 0.00061
# Epoch 344/400
# 20/20 - 1s - loss: 0.0097 - mean_absolute_error: 0.0770 - val_loss: 0.0031 - val_mean_absolute_error: 0.0398
#
# Epoch 00344: val_loss did not improve from 0.00061
# Epoch 345/400
# 20/20 - 1s - loss: 0.0082 - mean_absolute_error: 0.0710 - val_loss: 0.0020 - val_mean_absolute_error: 0.0324
#
# Epoch 00345: val_loss did not improve from 0.00061
# Epoch 346/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0683 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
#
# Epoch 00346: val_loss did not improve from 0.00061
# Epoch 347/400
# 20/20 - 1s - loss: 0.0087 - mean_absolute_error: 0.0754 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
#
# Epoch 00347: val_loss did not improve from 0.00061
# Epoch 348/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0673 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
#
# Epoch 00348: val_loss did not improve from 0.00061
# Epoch 349/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0711 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293
#
# Epoch 00349: val_loss did not improve from 0.00061
# Epoch 350/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0671 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
#
# Epoch 00350: val_loss did not improve from 0.00061
# Epoch 351/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0672 - val_loss: 8.7675e-04 - val_mean_absolute_error: 0.0225
#
# Epoch 00351: val_loss did not improve from 0.00061
# Epoch 352/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0657 - val_loss: 7.7075e-04 - val_mean_absolute_error: 0.0211
#
# Epoch 00352: val_loss did not improve from 0.00061
# Epoch 353/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0686 - val_loss: 7.0746e-04 - val_mean_absolute_error: 0.0205
#
# Epoch 00353: val_loss did not improve from 0.00061
# Epoch 354/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0678 - val_loss: 7.9745e-04 - val_mean_absolute_error: 0.0219
#
# Epoch 00354: val_loss did not improve from 0.00061
# Epoch 355/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0694 - val_loss: 6.5312e-04 - val_mean_absolute_error: 0.0197
#
# Epoch 00355: val_loss did not improve from 0.00061
# Epoch 356/400
# 20/20 - 1s - loss: 0.0061 - mean_absolute_error: 0.0622 - val_loss: 6.1336e-04 - val_mean_absolute_error: 0.0190
#
# Epoch 00356: val_loss did not improve from 0.00061
# Epoch 357/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0670 - val_loss: 6.0035e-04 - val_mean_absolute_error: 0.0188
#
# Epoch 00357: val_loss improved from 0.00061 to 0.00060, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 358/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0686 - val_loss: 7.3985e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00358: val_loss did not improve from 0.00060
# Epoch 359/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0658 - val_loss: 7.4925e-04 - val_mean_absolute_error: 0.0209
#
# Epoch 00359: val_loss did not improve from 0.00060
# Epoch 360/400
# 20/20 - 1s - loss: 0.0062 - mean_absolute_error: 0.0628 - val_loss: 6.5654e-04 - val_mean_absolute_error: 0.0197
#
# Epoch 00360: val_loss did not improve from 0.00060
# Epoch 361/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0705 - val_loss: 7.0049e-04 - val_mean_absolute_error: 0.0204
#
# Epoch 00361: val_loss did not improve from 0.00060
# Epoch 362/400
# 20/20 - 1s - loss: 0.0062 - mean_absolute_error: 0.0623 - val_loss: 6.1299e-04 - val_mean_absolute_error: 0.0191
#
# Epoch 00362: val_loss did not improve from 0.00060
# Epoch 363/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0683 - val_loss: 6.6317e-04 - val_mean_absolute_error: 0.0197
#
# Epoch 00363: val_loss did not improve from 0.00060
# Epoch 364/400
# 20/20 - 1s - loss: 0.0067 - mean_absolute_error: 0.0642 - val_loss: 6.2539e-04 - val_mean_absolute_error: 0.0192
#
# Epoch 00364: val_loss did not improve from 0.00060
# Epoch 365/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0666 - val_loss: 9.9307e-04 - val_mean_absolute_error: 0.0236
#
# Epoch 00365: val_loss did not improve from 0.00060
# Epoch 366/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0673 - val_loss: 6.5490e-04 - val_mean_absolute_error: 0.0195
#
# Epoch 00366: val_loss did not improve from 0.00060
# Epoch 367/400
# 20/20 - 1s - loss: 0.0077 - mean_absolute_error: 0.0714 - val_loss: 6.9287e-04 - val_mean_absolute_error: 0.0202
#
# Epoch 00367: val_loss did not improve from 0.00060
# Epoch 368/400
# 20/20 - 1s - loss: 0.0060 - mean_absolute_error: 0.0613 - val_loss: 6.8987e-04 - val_mean_absolute_error: 0.0202
#
# Epoch 00368: val_loss did not improve from 0.00060
# Epoch 369/400
# 20/20 - 1s - loss: 0.0067 - mean_absolute_error: 0.0640 - val_loss: 6.0857e-04 - val_mean_absolute_error: 0.0189
#
# Epoch 00369: val_loss did not improve from 0.00060
# Epoch 370/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0682 - val_loss: 5.8979e-04 - val_mean_absolute_error: 0.0187
#
# Epoch 00370: val_loss improved from 0.00060 to 0.00059, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 371/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0648 - val_loss: 6.0022e-04 - val_mean_absolute_error: 0.0188
#
# Epoch 00371: val_loss did not improve from 0.00059
# Epoch 372/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0678 - val_loss: 6.1296e-04 - val_mean_absolute_error: 0.0190
#
# Epoch 00372: val_loss did not improve from 0.00059
# Epoch 373/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0646 - val_loss: 5.9139e-04 - val_mean_absolute_error: 0.0187
#
# Epoch 00373: val_loss did not improve from 0.00059
# Epoch 374/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0672 - val_loss: 6.6465e-04 - val_mean_absolute_error: 0.0198
#
# Epoch 00374: val_loss did not improve from 0.00059
# Epoch 375/400
# 20/20 - 1s - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 6.1141e-04 - val_mean_absolute_error: 0.0190
#
# Epoch 00375: val_loss did not improve from 0.00059
# Epoch 376/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0668 - val_loss: 6.4466e-04 - val_mean_absolute_error: 0.0195
#
# Epoch 00376: val_loss did not improve from 0.00059
# Epoch 377/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0648 - val_loss: 5.6200e-04 - val_mean_absolute_error: 0.0181
#
# Epoch 00377: val_loss improved from 0.00059 to 0.00056, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 378/400
# 20/20 - 1s - loss: 0.0071 - mean_absolute_error: 0.0681 - val_loss: 5.7436e-04 - val_mean_absolute_error: 0.0183
#
# Epoch 00378: val_loss did not improve from 0.00056
# Epoch 379/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0646 - val_loss: 6.1329e-04 - val_mean_absolute_error: 0.0191
#
# Epoch 00379: val_loss did not improve from 0.00056
# Epoch 380/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0706 - val_loss: 5.5332e-04 - val_mean_absolute_error: 0.0180
#
# Epoch 00380: val_loss improved from 0.00056 to 0.00055, saving model to saved_models\deepssfp_bandremoval_2
# Epoch 381/400
# 20/20 - 1s - loss: 0.0063 - mean_absolute_error: 0.0628 - val_loss: 5.7782e-04 - val_mean_absolute_error: 0.0184
#
# Epoch 00381: val_loss did not improve from 0.00055
# Epoch 382/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0671 - val_loss: 6.5512e-04 - val_mean_absolute_error: 0.0198
#
# Epoch 00382: val_loss did not improve from 0.00055
# Epoch 383/400
# 20/20 - 1s - loss: 0.0069 - mean_absolute_error: 0.0647 - val_loss: 6.1332e-04 - val_mean_absolute_error: 0.0191
#
# Epoch 00383: val_loss did not improve from 0.00055
# Epoch 384/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0661 - val_loss: 5.9346e-04 - val_mean_absolute_error: 0.0186
#
# Epoch 00384: val_loss did not improve from 0.00055
# Epoch 385/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0656 - val_loss: 5.6999e-04 - val_mean_absolute_error: 0.0183
#
# Epoch 00385: val_loss did not improve from 0.00055
# Epoch 386/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0674 - val_loss: 6.0053e-04 - val_mean_absolute_error: 0.0188
#
# Epoch 00386: val_loss did not improve from 0.00055
# Epoch 387/400
# 20/20 - 1s - loss: 0.0066 - mean_absolute_error: 0.0639 - val_loss: 5.8418e-04 - val_mean_absolute_error: 0.0186
#
# Epoch 00387: val_loss did not improve from 0.00055
# Epoch 388/400
# 20/20 - 1s - loss: 0.0068 - mean_absolute_error: 0.0662 - val_loss: 6.4723e-04 - val_mean_absolute_error: 0.0196
#
# Epoch 00388: val_loss did not improve from 0.00055
# Epoch 389/400
# 20/20 - 1s - loss: 0.0074 - mean_absolute_error: 0.0690 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
#
# Epoch 00389: val_loss did not improve from 0.00055
# Epoch 390/400
# 20/20 - 1s - loss: 0.0063 - mean_absolute_error: 0.0619 - val_loss: 9.3464e-04 - val_mean_absolute_error: 0.0237
#
# Epoch 00390: val_loss did not improve from 0.00055
# Epoch 391/400
# 20/20 - 1s - loss: 0.0078 - mean_absolute_error: 0.0708 - val_loss: 9.6245e-04 - val_mean_absolute_error: 0.0238
#
# Epoch 00391: val_loss did not improve from 0.00055
# Epoch 392/400
# 20/20 - 1s - loss: 0.0070 - mean_absolute_error: 0.0659 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
#
# Epoch 00392: val_loss did not improve from 0.00055
# Epoch 393/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0668 - val_loss: 0.0015 - val_mean_absolute_error: 0.0291
#
# Epoch 00393: val_loss did not improve from 0.00055
# Epoch 394/400
# 20/20 - 1s - loss: 0.0084 - mean_absolute_error: 0.0716 - val_loss: 0.0016 - val_mean_absolute_error: 0.0291
#
# Epoch 00394: val_loss did not improve from 0.00055
# Epoch 395/400
# 20/20 - 1s - loss: 0.0076 - mean_absolute_error: 0.0705 - val_loss: 0.0015 - val_mean_absolute_error: 0.0289
#
# Epoch 00395: val_loss did not improve from 0.00055
# Epoch 396/400
# 20/20 - 1s - loss: 0.0065 - mean_absolute_error: 0.0636 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
#
# Epoch 00396: val_loss did not improve from 0.00055
# Epoch 397/400
# 20/20 - 1s - loss: 0.0073 - mean_absolute_error: 0.0671 - val_loss: 8.8335e-04 - val_mean_absolute_error: 0.0229
#
# Epoch 00397: val_loss did not improve from 0.00055
# Epoch 398/400
# 20/20 - 1s - loss: 0.0079 - mean_absolute_error: 0.0709 - val_loss: 9.1102e-04 - val_mean_absolute_error: 0.0233
#
# Epoch 00398: val_loss did not improve from 0.00055
# Epoch 399/400
# 20/20 - 1s - loss: 0.0064 - mean_absolute_error: 0.0634 - val_loss: 5.9974e-04 - val_mean_absolute_error: 0.0187
#
# Epoch 00399: val_loss did not improve from 0.00055
# Epoch 400/400
# 20/20 - 1s - loss: 0.0072 - mean_absolute_error: 0.0685 - val_loss: 5.9423e-04 - val_mean_absolute_error: 0.0187
#
# Epoch 00400: val_loss did not improve from 0.00055
# 1/1 [==============================] - 1s 917ms/step - loss: 5.8611e-04 - mean_absolute_error: 0.0186
# Training Complete.
# Summary: Loss: 0.02 Time Elapsed: 324.38 seconds

# %%
plotlib.plot_model_history(history)

# %%
ds.x_test.shape, ds.y_test.shape, predictions.shape
# Out:
# ((26, 128, 128, 4), (26, 128, 128, 2), (26, 128, 128, 2))

# %%
for i in range(26):
    plotlib.plot_model_results(i, ds.x_test, ds.y_test, predictions)
